# %%
*️⃣ SELECT all columns
*️⃣Filter columns(Use SELECT)
*️⃣Alias 'As' | Renaming the columns(USE SELECT)

➡️ SELECT *from smartphones_cleaned_v6;

➡️ SELECT brand_name , os , price from smartphones_cleaned_v6;

➡️ SELECT os AS OperatingSystem , price AS Global_Model , has_5g AS Has5G
from smartphones_cleaned_v6;
