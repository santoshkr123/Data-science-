# %%
🔷Day 319-DataScienceJourney(Tableau)
 ⭐ Topic : Tableau 
🎸 Today , I explored :
🔥Visualization Charts in Tableau
-Gantt
A Gantt chart shows tasks or activities over time, highlighting start date, duration, and end date. It’s widely used for:
Project timelines
Task scheduling
Resource planning

-Gantt bar :
A Gantt Bar is the mark type in Tableau that actually draws the bar in a Gantt chart.
 It visually represents duration or progress from a starting point.
