# %%
🍮 INSERT QUERY : 

➡️ CREATE DATABASE IHH_DB;

➡️USE IHH_DB;


➡️CREATE TABLE EMP ( 
EMP_ID INT PRIMARY KEY auto_increment,
 NAME VARCHAR(255) NOT NULL, 
 EMAIL VARCHAR(255) NOT NULL UNIQUE, 
 PASSWORD VARCHAR(255) NOT NULL );
 
 ➡️INSERT INTO IHH_DB.EMP(EMP_ID, NAME , EMAIL, PASSWORD)
 VALUES(1, 'SANTOSH KUMAR' , 'SANTOSH@GMAIL.COM' , '21564665');

➡️INSERT INTO IHH_DB.EMP(EMP_ID , NAME , EMAIL , PASSWORD)
VALUES(2,'RAVAN KUMAR' , 'RAVVAN@GMAIL.COM', '2132321')
