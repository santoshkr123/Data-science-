# %% [markdown]
# # DDL(Data Definition Language)

# %% [markdown]
# 🌟 DDL commands for Databases : Create | Drop
# 🔸 create database santosh;
# 🔸create database if not exists santosh;
#
# 🌟How to drop database?
# 🔸Drop database santosh;
# 🔸Drop database if not exists santosh;
