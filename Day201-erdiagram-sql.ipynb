# %% [markdown]
# # ER Diagram

# %% [markdown]
# Er Diagram stands for Entity Relationsip Diagram also known as ERD , is a diagram that displays the relationship of entity sets
# stored in a database . In other words ,ER diagrams help to explain the logical structure of a a databse .ER diagrams are created
# based on three basic concepts entites , atrributes ,relationship
#
# ER digram contain different symbols that use rectangles to represent entites , ovals to define attributes and diamond shapes
# to represent relationshp
