# %% [markdown]
# # Cards and Filters

# %%
🔥 Cards and Filters In Power BI
-Create a Number Card in Power Bi
-Date Card in Power Bi
-Relative Date filter 
-Create a Text Card
-Forma a card 
-Multi-Row Card
-Filter on visual
-Filter on this page
-Filter on All Pages
-Use Drill through
