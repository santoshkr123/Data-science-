# %% [markdown]
# # Sorting(Order By)

# %%
🔷Day 225-DataScienceJourney(SQL)
 ⭐ Topic : DML(DATA MANIPULATION LANGAUGE)
🎸 Today , I explored :
🔥 Sorting(Order By)
-Fundamental of sql sorting
-Sorting Ascending and Descending Order
-Sorting use with limit syntax
-Sorting us in multiple condition 

🔥What is data sorting order ?
-The SQL order by keyword
-The Order By keyword is used to sort the result set in ascending or descending order.
-The order by keyword sorts the records in ascending order by default ,
-To sort the records in descending order , use the DESC keyword .

# %%
select brand_name , model , screen_size 
from smartphones_cleaned_v6
where brand_name='realme'
order by screen_size Desc;

select brand_name , model , screen_size 
from smartphones_cleaned_v6
where brand_name='realme'
order by screen_size Desc limit 5;

select model , battery_capacity
from smartphones_cleaned_v6
order by battery_capacity  desc limit 2 ,1;

select brand_name , model , battery_capacity 
from smartphones_cleaned_v6
where brand_name ='realme'
order by battery_capacity desc limit 2, 3 ; 

select brand_name , model , battery_capacity
from smartphones_cleaned_v6
where brand_name ='realme'
order by battery_capacity asc limit 4, 1;

select model , brand_name  , rating 
from smartphones_cleaned_v6
order by brand_name asc , rating desc ;
