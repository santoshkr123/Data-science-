# %%
🔷Day 316-DataScienceJourney(Tableau)
 ⭐ Topic : Tableau AND one SQL solved today!
🎸 Today , I explored :
🔥Visualization Charts in Tableau
-Discrete Line Chart
-Continuous Line Chart
-Discrete Area Chart
-Continuous Area Chart

| Chart Type      | Axis Type    | Best For              |
| --------------- | ------------ | --------------------- |
| Discrete Line   | Categories   | Category comparison   |
| Continuous Line | Numeric/Date | Trend analysis        |
| Discrete Area   | Categories   | Category contribution |
| Continuous Area | Numeric/Date | Trend + volume        |
