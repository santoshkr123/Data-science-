# %% [markdown]
# # Constrains in MYSQL

# %% [markdown]
# 🔸 Constraints - SQL constraints are used to specify rules for the data in a table
# 🔸NOT NULL - Ensures that a columns have a NULL value
# 🔸UNIQUE -Ensures that all values in a columns are different
# 🔸PRIMARY KEY - A combinations of a NOT NULL and UNIQUE identifies each row in a table.
