# %% [markdown]
# # SUB -Query

# %%
What is Sub Query ?
-Scalar , Row , Table , Subquery
-Correlated Subquery 
-Subquery used with Select , from 
-Subquery used with where , having 
-Subquery used with Insert , update , delete

🔥 SUB-QUERY - It is a select statement , a subquery is a query within another query. It is a select statement that is nested inside another select , insert , update , or delete statement . 
The subquery is executed first , and its result si then used as a parameter or condition for the outer query .
