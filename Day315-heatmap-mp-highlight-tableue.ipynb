# %%
🔷Day 315-DataScienceJourney(Tableau)
⭐ Topic : Tableau AND one SQL solved today!
🎸 Today , I explored :
🔥Visualization Charts in Tableau
-Heat Map
🔹 What it is

A Heat Map uses color intensity (and sometimes size) to show the magnitude of values across two dimensions.

🔹 Best used when

Comparing patterns or trends

Identifying high vs low values quickly

Working with large datasets

🔹 Example

Sales by Product Category vs Region

Website traffic by Day vs Hour

🔹 How to create in Tableau

Drag Dimension 1 → Rows

Drag Dimension 2 → Columns

Drag Measure (e.g., Sales) → Color

Change Marks to Square

Adjust color gradient

🔹 Key Tip

Use diverging color palettes for performance-based analysis (e.g., low to high sales).
                            
-Map
                            2️⃣ Map (Geographic Map)
🔹 What it is

A Map visualization plots data using geographic locations such as country, state, city, or postal code.

🔹 Best used when

Showing regional distribution

Comparing performance across locations

Identifying geographic patterns

🔹 Example

Sales by Country/State

Customer count by City

🔹 How to create in Tableau

Drag a Geographic Dimension (e.g., Country) → View

Tableau automatically creates a map

Drag a Measure → Color or Size

Choose Symbol Map or Filled Map

🔹 Key Tip

Use Filled Maps for regions and Symbol Maps for precise locations.

-Highlight tables
🔹 What it is

A Highlight Table is a table enhanced with color, combining text values + heat map effect.

🔹 Best used when

You need exact values AND visual comparison

Comparing multiple measures across categories

🔹 Example

Sales by Region and Quarter

Performance scorecards

🔹 How to create in Tableau

Drag Dimension 1 → Rows

Drag Dimension 2 → Columns

Drag Measure → Text

Drag the same Measure → Color

Choose Square marks if needed

🔹 Key Tip

Highlight Tables are perfect for management dashboards because they balance clarity and insight.

🔥 Quick Comparison
Visualization	Best For	Strength
Heat Map	Pattern detection	Fast insight
Map	Geographic analysis	Location-based trends
Highlight Table	Detailed comparison	Values + visuals
