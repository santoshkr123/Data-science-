# %% [markdown]
# # AMazon Global SuperStore

# %%
🔥 Amazon Global SuperStore
Step 1 : Connecting Database(Excel , SQL ,)
Step 2 :Analyzing Tables and relations
Step 3 : Data Cleaning - Power Query Editor DAX
Step 4 : Developing Visualization Model
 - Slicers | Cards | Insert Background Formatting
-Pie | Donut | Stacked Column Charts
-Clustered Bar chart | Formatting Report
