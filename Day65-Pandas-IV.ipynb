# %% [markdown]
# # Pandas
# # converting dictionary into dataframe

# %%
import pandas as pd
pd.read_csv('https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/titanic.csv')

# %%
d={"key1":[1,2,3,4,5],
   "key2":[7,8,9,10,11],
  "key3":[10,12,13,14,55],
"key4":[77,89,63,45,66]
}

d
# Out:
# {'key1': [1, 2, 3, 4, 5],
#  'key2': [7, 8, 9, 10, 11],
#  'key3': [10, 12, 13, 14, 55],
#  'key4': [77, 89, 63, 45, 66]}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3  key4
# 0     1     7    10    77
# 1     2     8    12    89
# 2     3     9    13    63
# 3     4    10    14    45
# 4     5    11    55    66

# %%
df1=pd.read_csv('taxonomy.csv')

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.dropna()
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.dropna(inplace=True)

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df2=pd.read_csv('taxonomy.csv')

# %%
df2
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df2.dropna(axis=1)
# Out:
#     taxonomy_id                          name
# 0           101                     Emergency
# 1        101-01             Disaster Response
# 2        101-02                Emergency Cash
# 3     101-02-01             Help Pay for Food
# 4     101-02-02       Help Pay for Healthcare
# ..          ...                           ...
# 285   111-01-07              Workplace Rights
# 286      111-02                     Mediation
# 287      111-03                        Notary
# 288      111-04                Representation
# 289      111-05  Translation & Interpretation
#
# [290 rows x 2 columns]

# %%
df2
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df2.dropna(axis=1,inplace=True)

# %%
df2
# Out:
#     taxonomy_id                          name
# 0           101                     Emergency
# 1        101-01             Disaster Response
# 2        101-02                Emergency Cash
# 3     101-02-01             Help Pay for Food
# 4     101-02-02       Help Pay for Healthcare
# ..          ...                           ...
# 285   111-01-07              Workplace Rights
# 286      111-02                     Mediation
# 287      111-03                        Notary
# 288      111-04                Representation
# 289      111-05  Translation & Interpretation
#
# [290 rows x 2 columns]

# %% [markdown]
# # fillna()

# %%
df3=pd.read_csv('taxonomy.csv')

# %%
df3
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df3.fillna("DataScience")
# Out:
#     taxonomy_id                          name    parent_id  \
# 0           101                     Emergency  DataScience
# 1        101-01             Disaster Response          101
# 2        101-02                Emergency Cash          101
# 3     101-02-01             Help Pay for Food       101-02
# 4     101-02-02       Help Pay for Healthcare       101-02
# ..          ...                           ...          ...
# 285   111-01-07              Workplace Rights       111-01
# 286      111-02                     Mediation          111
# 287      111-03                        Notary          111
# 288      111-04                Representation          111
# 289      111-05  Translation & Interpretation          111
#
#               parent_name
# 0             DataScience
# 1               Emergency
# 2               Emergency
# 3          Emergency Cash
# 4          Emergency Cash
# ..                    ...
# 285  Advocacy & Legal Aid
# 286                 Legal
# ...

# %%
df3
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df3.fillna("DataScience",inplace=True)

# %%
df3
# Out:
#     taxonomy_id                          name    parent_id  \
# 0           101                     Emergency  DataScience
# 1        101-01             Disaster Response          101
# 2        101-02                Emergency Cash          101
# 3     101-02-01             Help Pay for Food       101-02
# 4     101-02-02       Help Pay for Healthcare       101-02
# ..          ...                           ...          ...
# 285   111-01-07              Workplace Rights       111-01
# 286      111-02                     Mediation          111
# 287      111-03                        Notary          111
# 288      111-04                Representation          111
# 289      111-05  Translation & Interpretation          111
#
#               parent_name
# 0             DataScience
# 1               Emergency
# 2               Emergency
# 3          Emergency Cash
# 4          Emergency Cash
# ..                    ...
# 285  Advocacy & Legal Aid
# 286                 Legal
# ...

# %%
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # groupby

# %%
g=df.groupby('Survived')
g.sum()
# Out:
#           PassengerId  Pclass  \
# Survived
# 0              245412    1390
# 1              151974     667
#
#                                                        Name  \
# Survived
# 0         Braund, Mr. Owen HarrisAllen, Mr. William Henr...
# 1         Cumings, Mrs. John Bradley (Florence Briggs Th...
#
#                                                         Sex       Age  SibSp  \
# Survived
# 0         malemalemalemalemalemalemalefemalemalefemalema...  12985.50    304
# 1         femalefemalefemalefemalefemalefemalefemalefema...   8219.67    162
#
#           Parch                                             Ticket  \
# Survived
# 0           181  A/5 2117137345033087717463349909A/5. 215134708...
# 1           159  PC 17599STON/O2. 3101282113803347742237736PP 9...
#
#                 Fare                                              Cabin  \
# Survived
# 0         12142.7199  E46C23 C25 C27B30C83F G73E31A5D26C110B58 B60D2...
# ...

# %%
g.mean(numeric_only=True)
# Out:
#           PassengerId    Pclass        Age     SibSp     Parch       Fare
# Survived
# 0          447.016393  2.531876  30.626179  0.553734  0.329690  22.117887
# 1          444.368421  1.950292  28.343690  0.473684  0.464912  48.395408

# %%
g.max(numeric_only=True)
# Out:
#           PassengerId  Pclass   Age  SibSp  Parch      Fare
# Survived
# 0                 891       3  74.0      8      6  263.0000
# 1                 890       3  80.0      4      5  512.3292

# %%
g.min(numeric_only=True)
# Out:
#           PassengerId  Pclass   Age  SibSp  Parch  Fare
# Survived
# 0                   1       1  1.00      0      0   0.0
# 1                   2       1  0.42      0      0   0.0

# %%
g1=df.groupby('Pclass')

# %%
g1.sum()
# Out:
#         PassengerId  Survived  \
# Pclass
# 1             99705       136
# 2             82056        87
# 3            215625       119
#
#                                                      Name  \
# Pclass
# 1       Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       Nasser, Mrs. Nicholas (Adele Achem)Hewlett, Mr...
# 3       Braund, Mr. Owen HarrisHeikkinen, Miss LainaAl...
#
#                                                       Sex      Age  SibSp  \
# Pclass
# 1       femalefemalemalefemalemalemalemalefemalemalema...  7111.42     90
# 2       femalefemalemalemalemalemalefemalefemalefemale...  5168.83     74
# 3       malefemalemalemalemalefemalefemalemalemalefema...  8924.92    302
#
#         Parch                                             Ticket        Fare  \
# Pclass
# 1          77  PC 175991138031746311378311378819950PC 17601PC...  18177.4125
# 2          70  237736248706244373239865248698C.A. 2457911668S...   3801.8417
# ...

# %%
g1.mean(numeric_only=True)
# Out:
#         PassengerId  Survived        Age     SibSp     Parch       Fare
# Pclass
# 1        461.597222  0.629630  38.233441  0.416667  0.356481  84.154687
# 2        445.956522  0.472826  29.877630  0.402174  0.380435  20.662183
# 3        439.154786  0.242363  25.140620  0.615071  0.393075  13.675550

# %%
g1.max(numeric_only=True)['Fare']
# Out:
# Pclass
# 1    512.3292
# 2     73.5000
# 3     69.5500
# Name: Fare, dtype: float64

# %%
g1.min(numeric_only=True)
# Out:
#         PassengerId  Survived   Age  SibSp  Parch  Fare
# Pclass
# 1                 2         0  0.92      0      0   0.0
# 2                10         0  0.67      0      0   0.0
# 3                 1         0  0.42      0      0   0.0

# %%
g1.min(numeric_only=True).T
# Out:
# Pclass          1      2     3
# PassengerId  2.00  10.00  1.00
# Survived     0.00   0.00  0.00
# Age          0.92   0.67  0.42
# SibSp        0.00   0.00  0.00
# Parch        0.00   0.00  0.00
# Fare         0.00   0.00  0.00

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df4=df[['PassengerId','Survived','Pclass','Name']][0:3]

# %%
df5=df[['PassengerId','Survived','Pclass','Name']][5:8]

# %%
pd.concat([df4,df5])
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
#
#                                                 Name
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                              Heikkinen, Miss Laina
# 5                                   Moran, Mr. James
# 6                            McCarthy, Mr. Timothy J
# 7                      Palsson, Master Gosta Leonard

# %%
df4
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                              Heikkinen, Miss Laina

# %%
df5
# Out:
#    PassengerId  Survived  Pclass                           Name
# 5            6         0       3               Moran, Mr. James
# 6            7         0       1        McCarthy, Mr. Timothy J
# 7            8         0       3  Palsson, Master Gosta Leonard

# %%
pd.concat([df4,df5],axis=1)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          1.0       0.0     3.0
# 1          2.0       1.0     1.0
# 2          3.0       1.0     3.0
# 5          NaN       NaN     NaN
# 6          NaN       NaN     NaN
# 7          NaN       NaN     NaN
#
#                                                 Name  PassengerId  Survived  \
# 0                            Braund, Mr. Owen Harris          NaN       NaN
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...          NaN       NaN
# 2                              Heikkinen, Miss Laina          NaN       NaN
# 5                                                NaN          6.0       0.0
# 6                                                NaN          7.0       0.0
# 7                                                NaN          8.0       0.0
#
#    Pclass                           Name
# 0     NaN                            NaN
# 1     NaN                            NaN
# 2     NaN                            NaN
# ...

# %% [markdown]
# # merge()

# %%
data1=pd.DataFrame({'key1':[1,2,3,4,5],
              'key2':[7,8,9,10,11],
              'key3':[12,13,14,15,16],
              'key4':[17,18,19,20,21]
             })
data1
# Out:
#    key1  key2  key3  key4
# 0     1     7    12    17
# 1     2     8    13    18
# 2     3     9    14    19
# 3     4    10    15    20
# 4     5    11    16    21

# %%
data2=pd.DataFrame({'key1':[1,2,3,44,55],
              'key6':[7,8,9,100,111],
              'key7':[12,133,141,150,16],
              'key8':[17,180,190,200,21]
             })
data2
# Out:
#    key1  key6  key7  key8
# 0     1     7    12    17
# 1     2     8   133   180
# 2     3     9   141   190
# 3    44   100   150   200
# 4    55   111    16    21

# %%
pd.merge(data1,data2)
# Out:
#    key1  key2  key3  key4  key6  key7  key8
# 0     1     7    12    17     7    12    17
# 1     2     8    13    18     8   133   180
# 2     3     9    14    19     9   141   190

# %%
data1
# Out:
#    key1  key2  key3  key4
# 0     1     7    12    17
# 1     2     8    13    18
# 2     3     9    14    19
# 3     4    10    15    20
# 4     5    11    16    21

# %%
data2
# Out:
#    key1  key6  key7  key8
# 0     1     7    12    17
# 1     2     8   133   180
# 2     3     9   141   190
# 3    44   100   150   200
# 4    55   111    16    21

# %%
pd.merge(data1,data2,how='left')
# Out:
#    key1  key2  key3  key4  key6   key7   key8
# 0     1     7    12    17   7.0   12.0   17.0
# 1     2     8    13    18   8.0  133.0  180.0
# 2     3     9    14    19   9.0  141.0  190.0
# 3     4    10    15    20   NaN    NaN    NaN
# 4     5    11    16    21   NaN    NaN    NaN

# %%
data1
# Out:
#    key1  key2  key3  key4
# 0     1     7    12    17
# 1     2     8    13    18
# 2     3     9    14    19
# 3     4    10    15    20
# 4     5    11    16    21

# %%
data2
# Out:
#    key1  key6  key7  key8
# 0     1     7    12    17
# 1     2     8   133   180
# 2     3     9   141   190
# 3    44   100   150   200
# 4    55   111    16    21

# %%
pd.merge(data1,data2,how='right')
# Out:
#    key1  key2  key3  key4  key6  key7  key8
# 0     1   7.0  12.0  17.0     7    12    17
# 1     2   8.0  13.0  18.0     8   133   180
# 2     3   9.0  14.0  19.0     9   141   190
# 3    44   NaN   NaN   NaN   100   150   200
# 4    55   NaN   NaN   NaN   111    16    21

# %%
pd.merge(data1,data2,how='outer')
# Out:
#    key1  key2  key3  key4   key6   key7   key8
# 0     1   7.0  12.0  17.0    7.0   12.0   17.0
# 1     2   8.0  13.0  18.0    8.0  133.0  180.0
# 2     3   9.0  14.0  19.0    9.0  141.0  190.0
# 3     4  10.0  15.0  20.0    NaN    NaN    NaN
# 4     5  11.0  16.0  21.0    NaN    NaN    NaN
# 5    44   NaN   NaN   NaN  100.0  150.0  200.0
# 6    55   NaN   NaN   NaN  111.0   16.0   21.0

# %%
data1
# Out:
#    key1  key2  key3  key4
# 0     1     7    12    17
# 1     2     8    13    18
# 2     3     9    14    19
# 3     4    10    15    20
# 4     5    11    16    21

# %%
data2
# Out:
#    key1  key6  key7  key8
# 0     1     7    12    17
# 1     2     8   133   180
# 2     3     9   141   190
# 3    44   100   150   200
# 4    55   111    16    21

# %%
pd.merge(data1,data2,how='cross')
# Out:
#     key1_x  key2  key3  key4  key1_y  key6  key7  key8
# 0        1     7    12    17       1     7    12    17
# 1        1     7    12    17       2     8   133   180
# 2        1     7    12    17       3     9   141   190
# 3        1     7    12    17      44   100   150   200
# 4        1     7    12    17      55   111    16    21
# 5        2     8    13    18       1     7    12    17
# 6        2     8    13    18       2     8   133   180
# 7        2     8    13    18       3     9   141   190
# 8        2     8    13    18      44   100   150   200
# 9        2     8    13    18      55   111    16    21
# 10       3     9    14    19       1     7    12    17
# 11       3     9    14    19       2     8   133   180
# 12       3     9    14    19       3     9   141   190
# 13       3     9    14    19      44   100   150   200
# 14       3     9    14    19      55   111    16    21
# 15       4    10    15    20       1     7    12    17
# ...

# %%
data1
# Out:
#    key1  key2  key3  key4
# 0     1     7    12    17
# 1     2     8    13    18
# 2     3     9    14    19
# 3     4    10    15    20
# 4     5    11    16    21

# %%
data2
# Out:
#    key1  key6  key7  key8
# 0     1     7    12    17
# 1     2     8   133   180
# 2     3     9   141   190
# 3    44   100   150   200
# 4    55   111    16    21

# %% [markdown]
# # join method

# %%
data1=pd.DataFrame({"key1":[1,2,3,4,5],
              "key2":[6,7,8,9,10],
              "key3":[11,12,13,14,15]},
                   
             index=['a','b','c','d','e']
                  )
    

data1
# Out:
#    key1  key2  key3
# a     1     6    11
# b     2     7    12
# c     3     8    13
# d     4     9    14
# e     5    10    15

# %%
data2=pd.DataFrame({"key11":[1,2,30,40,5],
              "key22":[6,7,80,9,10],
              "key33":[11,122,133,14,15]},
                   
             index=['a','b','f','g','e']
                  )
    

data2
# Out:
#    key11  key22  key33
# a      1      6     11
# b      2      7    122
# f     30     80    133
# g     40      9     14
# e      5     10     15

# %%
data1.join(data2)
# Out:
#    key1  key2  key3  key11  key22  key33
# a     1     6    11    1.0    6.0   11.0
# b     2     7    12    2.0    7.0  122.0
# c     3     8    13    NaN    NaN    NaN
# d     4     9    14    NaN    NaN    NaN
# e     5    10    15    5.0   10.0   15.0

# %%
data1
# Out:
#    key1  key2  key3
# a     1     6    11
# b     2     7    12
# c     3     8    13
# d     4     9    14
# e     5    10    15

# %%
data2
# Out:
#    key11  key22  key33
# a      1      6     11
# b      2      7    122
# f     30     80    133
# g     40      9     14
# e      5     10     15

# %%
data1.join(data2,how='right')
# Out:
#    key1  key2  key3  key11  key22  key33
# a   1.0   6.0  11.0      1      6     11
# b   2.0   7.0  12.0      2      7    122
# f   NaN   NaN   NaN     30     80    133
# g   NaN   NaN   NaN     40      9     14
# e   5.0  10.0  15.0      5     10     15

# %%
data1.join(data2,how='inner')
# Out:
#    key1  key2  key3  key11  key22  key33
# a     1     6    11      1      6     11
# b     2     7    12      2      7    122
# e     5    10    15      5     10     15

# %%
data1
# Out:
#    key1  key2  key3
# a     1     6    11
# b     2     7    12
# c     3     8    13
# d     4     9    14
# e     5    10    15

# %%
data2
# Out:
#    key11  key22  key33
# a      1      6     11
# b      2      7    122
# f     30     80    133
# g     40      9     14
# e      5     10     15

# %%
data1.join(data2,how='outer')
# Out:
#    key1  key2  key3  key11  key22  key33
# a   1.0   6.0  11.0    1.0    6.0   11.0
# b   2.0   7.0  12.0    2.0    7.0  122.0
# c   3.0   8.0  13.0    NaN    NaN    NaN
# d   4.0   9.0  14.0    NaN    NaN    NaN
# e   5.0  10.0  15.0    5.0   10.0   15.0
# f   NaN   NaN   NaN   30.0   80.0  133.0
# g   NaN   NaN   NaN   40.0    9.0   14.0

# %%
data1.join(data2,how='cross')
# Out:
#     key1  key2  key3  key11  key22  key33
# 0      1     6    11      1      6     11
# 1      1     6    11      2      7    122
# 2      1     6    11     30     80    133
# 3      1     6    11     40      9     14
# 4      1     6    11      5     10     15
# 5      2     7    12      1      6     11
# 6      2     7    12      2      7    122
# 7      2     7    12     30     80    133
# 8      2     7    12     40      9     14
# 9      2     7    12      5     10     15
# 10     3     8    13      1      6     11
# 11     3     8    13      2      7    122
# 12     3     8    13     30     80    133
# 13     3     8    13     40      9     14
# 14     3     8    13      5     10     15
# 15     4     9    14      1      6     11
# 16     4     9    14      2      7    122
# 17     4     9    14     30     80    133
# 18     4     9    14     40      9     14
# 19     4     9    14      5     10     15
# 20     5    10    15      1      6     11
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['INR_Fare']=df['Fare'].apply(lambda x:x*80)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
def eru_inr(x):
    return x*80

df['INR_Fare']=df['Fare'].apply(eru_inr)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['NEw_Length']=df['Name'].apply(len)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
def cat_fare(x):
    if x<10:
        return "cheap"
    elif x>10 and x>20:
        return "mid"
    else:
        return "high"

df['Category']=df['Fare'].apply(cat_fare)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
