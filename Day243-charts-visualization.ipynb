# %% [markdown]
# # Charts Visualization

# %%
🔥 Charts Visualization Tools
-Intro visualization charts
-Create a waterfall chart
-Create a Gauge chart
-Create Line chart
-Line chart Drill with Slicer
-Create an Area chart
-Create an Stacked Area Chart
-Line vs Stacked Column chart
-Line vs Clustered Column chart
-Create Scatterplot
Create Tree Map
