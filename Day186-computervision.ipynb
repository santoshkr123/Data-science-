# %% [markdown]
#  # Computer Vision

# %% [markdown]
# 🔷 Computer Vision - Computer Vision is a field of artificial intelligence that enables computers to interpret and make decisions based on visual data from the world.
# Goal : To automate tasks that the human visual system can do,such as recognizing objects ,detecting events and understanding scenes.
#
# Importance and Applications :
# -Medical Imaging
# -Automonous Vehicles
# -Facial Recognition
# -Retail and ecommerce
# -Agriculture
# -Manufacturing
# -Augmented Reality(AR)
#
# *Ans Some important processing during computer vision :
# -Images Acquisition
# -Images Processing
# -Feature Extraction
# -Pattern Recognition
# -Pixels and Image Recognition
# -Colors Spaces(RGB,HSV)
# -Image Filtering
# -Edge Detection
# -Object Detection
# -Classification ->classification+ localization->object detection->Instance Segmentation
