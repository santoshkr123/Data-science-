# %% [markdown]
#  📘 𝗥𝗲𝗴𝗿𝗲𝘀𝘀𝗶𝗼𝗻 𝗶𝗻 𝗠𝗮𝗰𝗵𝗶𝗻𝗲 𝗟𝗲𝗮𝗿𝗻𝗶𝗻𝗴 – 𝗦𝗶𝗺𝗽𝗹𝗶𝗳𝗶𝗲𝗱
# Regression is a 𝘀𝘂𝗽𝗲𝗿𝘃𝗶𝘀𝗲𝗱 𝗹𝗲𝗮𝗿𝗻𝗶𝗻𝗴 technique used to 𝗽𝗿𝗲𝗱𝗶𝗰𝘁 𝗮 𝗰𝗼𝗻𝘁𝗶𝗻𝘂𝗼𝘂𝘀 𝘃𝗮𝗹𝘂𝗲.
# 📌 𝗧𝗵𝗶𝗻𝗸 𝗼𝗳 𝗶𝘁 𝗹𝗶𝗸𝗲 𝘁𝗵𝗶𝘀:
# You're trying to 𝗽𝗿𝗲𝗱𝗶𝗰𝘁 𝗮 𝗻𝘂𝗺𝗯𝗲𝗿 — like the price of a house, someone's salary, or a student's marks — based on other information.

# %% [markdown]
# 📘 𝗟𝗶𝗻𝗲𝗮𝗿 𝗥𝗲𝗴𝗿𝗲𝘀𝘀𝗶𝗼𝗻 – 𝗦𝗶𝗺𝗽𝗹𝗶𝗳𝗶𝗲𝗱
# 𝗟𝗶𝗻𝗲𝗮𝗿 𝗥𝗲𝗴𝗿𝗲𝘀𝘀𝗶𝗼𝗻 is the most basic form of regression used to model the 𝗿𝗲𝗹𝗮𝘁𝗶𝗼𝗻𝘀𝗵𝗶𝗽 𝗯𝗲𝘁𝘄𝗲𝗲𝗻 𝘁𝘄𝗼 𝘃𝗮𝗿𝗶𝗮𝗯𝗹𝗲𝘀 by fitting a 𝘀𝘁𝗿𝗮𝗶𝗴𝗵𝘁 𝗹𝗶𝗻𝗲 through the data.

# %% [markdown]
# 🧮 𝗘𝗾𝘂𝗮𝘁𝗶𝗼𝗻 𝗼𝗳 𝗟𝗶𝗻𝗲𝗮𝗿 𝗥𝗲𝗴𝗿𝗲𝘀𝘀𝗶𝗼𝗻:
#  𝘺=𝘮𝘹+𝘤
# y: Predicted output (dependent variable)
# x: Input (independent variable)
# m: Slope (shows how much y changes with x)
# c: Intercept (where the line crosses the y-axis)

# %% [markdown]
# 🎯 𝗚𝗼𝗮𝗹:
# Minimize the difference between predicted values and actual values using a method called Least Squares.

# %% [markdown]
# 📌 Real-Life Example:
# Predict someone's exam score based on the number of study hours.

# %% [markdown]
# Study Hours (x)                 Exam Score (y)
# 1                                50
# 2                                60
# 3                                65
# 4                                70

# %% [markdown]
# A linear regression model would draw the 𝗯𝗲𝘀𝘁-𝗳𝗶𝘁 𝘀𝘁𝗿𝗮𝗶𝗴𝗵𝘁 𝗹𝗶𝗻𝗲 that approximates this relationship.

# %% [markdown]
# ✅ 𝗨𝘀𝗲 𝗖𝗮𝘀𝗲𝘀:
# Predicting house prices
# Estimating sales based on advertising
# Forecasting stock prices (basic level)
