# %%
🔥 Creating a charts
->Create a columns chart
->Create a Stacked column in Power BI
->Create a Pie Chart in Power BI
->Create a DONOT chart in Power BI
->Create a Funnel chart in Power BI
->Create a Ribbon chart In Power BI
->What is included and exculde
> View Data and Export in CSV 

🔥One Leetcode SQL Problem Solved ->Rank Scores
