# %% [markdown]
# # Case study with pgAdmin4 Software

# %% [markdown]
# Database: create, Drop | table : create ,insert ,Drop
# 🔷 Today, I explored on the topic :
# *client requirements:
# 1.Database Name : IHH_College
# 2.Student Registration Details :
# Student Name|Email Id|Mobile Number|Create Password
# 3.Student Login Details: Mobile Number|Password|Student ID.
#
#
# 🌟 Case study with pgAdmin4 Software
# -Both Database done with GUI and SQL Syntax
#
# 🌟Create DATABASE ihh_college;
# Use ihh_college;
# create TABLE st_details(st_id INT(11),st_name VARCHAR(255),st_email VARCHAR(255),st_mob VARCHAR(255),
# st_pass VARCHAR(255) );
# select * from ihh_college.st_details;
# insert into st_details(st_id,st_name,st_email,st_mob,st_pass)VALUES(1,'Santosh Kumar','santosh@gmail.com',
# 791565656,123458);
