# %% [markdown]
# # Modify Alter

# %%
🌟 ALTER TABLE : MODIFY Columns in Alter Table
Alter Table Employee_Grade
Modify Grade varchar(80) Not Null;

🌟Multiple Modification in Alter Table 
Alter Table Employee_Grade
Modify First_Name varchar(10),
Modify Last_Name varchar(),
Modify New_City varchar()
