# %%
🔷Day 324-DataScienceJourney(Tableau)
⭐ Topic : Tableau AND one SQL solved today!
🎸 Today , I explored :
🔥Visualization Charts in Tableau
-Box and whisker plots
A Box and Whisker Plot (Box Plot) is a powerful way to visualize the distribution, spread, and outliers in your data. Tableau makes it easy to build and interpret these charts.

📊 What a Box and Whisker Plot Shows

A box plot summarizes data using five key statistics:

Minimum – lowest value (excluding outliers)

First Quartile (Q1) – 25% of data below this value

Median (Q2) – middle value

Third Quartile (Q3) – 75% of data below this value

Maximum – highest value (excluding outliers)

🔹 Box = Interquartile Range (IQR = Q3 − Q1)
🔹 Line inside the box = Median
🔹 Whiskers = range within 1.5 × IQR
🔹 Dots = Outliers

🧠 When to Use Box Plots

Use box and whisker plots when you want to:

Compare distributions across categories

Identify outliers

Analyze data spread and skewness

Compare performance, sales, or scores across groups

Examples:

Sales distribution by Region

Exam scores by Class

Delivery time by Shipping Method

🛠️ How to Create a Box and Whisker Plot in Tableau
Method 1: Using Show Me (Recommended)

Drag a dimension (e.g., Region) to Columns

Drag a measure (e.g., Sales) to Rows

Click Show Me

Select Box-and-Whisker Plot

✅ Tableau automatically builds the chart.
