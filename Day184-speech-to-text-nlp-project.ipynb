# %%
pip install speechrecognition pydub
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 49.4 MB/s eta 0:00:00:00:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os 
import tempfile
import speech_recognition as sr
from pydub import AudioSegment as AS

# %%
audio_path ="/kaggle/input/speech/speech (1).mp3"

# %%
audio= AS.from_file(audio_path)

# %%
audio
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
audio = audio.set_frame_rate(16000).set_channels(1)

# %%
temp_wav_file = tempfile.NamedTemporaryFile(delete=False,suffix=".wav")

# %%
audio.export(temp_wav_file,format="wav")

# %% [markdown]
# # recognition

# %%
recognizer = sr.Recognizer()

# %%
with sr.AudioFile(temp_wav_file)as source :
    print("transcribinng.. please wait")
    audio_data = recognizer.record(source)
    try:
        text=recognizer.recognize_google(audio_data)
        print("transcribtion succeessfull")
        print(text)
    except sr.UnknownValueError:
        print("could undersstant the auido try again")
    except sr.RequestError:
        print("connection faild")
# Out:
# transcribinng.. please wait
# transcribtion succeessfull
# Indian cricket Superstar Virat Kohli is well known for his own field Antics which often entertain fans just as much as his batting heroics from urging the crowd to cheer louder to mimicking his teammates kohli's exuberance is always on display

# %%
# !pip install -U openai-whisper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.2/803.2 kB 11.1 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 108.0 MB/s eta 0:00:0000:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 82.5 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 37.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.0 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 32.0 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.0 MB/s eta 0:00:0000:0100:01
# ...

# %%
import whisper

model = whisper.load_model("base")
result = model.transcribe("/kaggle/input/speech/speech (1).mp3")
print(result["text"])
# Out:
# 100%|███████████████████████████████████████| 139M/139M [00:06<00:00, 23.1MiB/s]
# /usr/local/lib/python3.11/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  Indian cricket superstar Virat Kohli is well known for his own field antics. Which often entertain fans just as much as his batting heroics. From urging the crowd to cheer louder to mimicking his teammates. Kohli's exuberance is always on display.
