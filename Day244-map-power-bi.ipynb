# %% [markdown]
# # Creating a Map

# %%
🔥 Creating a Map
-Introduction Map visualization
-Create a Basic Map
-Create a Filled Map
-Create map with Pie chart
-Use slicer with Map of India 
Formatting of maps
-Background of map
-International continent vs Do not
