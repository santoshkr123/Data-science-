# %% [markdown]
# # Insert multiple values

# %%
create table emp(
emp_id int primary key auto_increment,
name varchar(255),
email varchar(255),
password varchar(255)
);
insert into ihh_db.emp
values
(null,'Shyam','shyam@gmail.com','12345'),
(null,'Radha','radha@gmail.com','1589'),
(null,'geeta','geeta@gmail.com','564564'),
(null,'meena','meena@gmail.com','654645');
