# %%
🔷Day 327-DataScienceJourney(Tableau)
 ⭐ Topic : Tableau AND one SQL solved today!
🎸 Today , I explored :
🔥Visualization Charts in Tableau
-Making Dashboard In tableau

A Tableau Dashboard is a collection of related worksheets arranged on one screen to analyze data and make decisions easily.
