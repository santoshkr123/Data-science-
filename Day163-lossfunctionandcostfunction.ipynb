# %% [markdown]
# # Cost Function And Loss Function
# # Regression and Classification

# %% [markdown]
# *Loss Function :- A way to calculate Error / diff bewteen predicted and acutal
# -Jab mai indivisual JaKe error ko calculate karta hu -loss function
# *Cost Function : Pure Batch ke lye calculate karta hai wo hai cost function
#
# *Regression
# 1. Mean Square Error
# -Easy to Interpret
# -Only one Minima
# -differentiable
# Disadvantage :
# -Very sensitive to outluers or
# Not Robust to outliers
# -Unit is Squared
#
# 2. Mean Absolute Error
# -Robust to outliers
# -easy to interpret
# Disadvantage
# -Not Differentiable
#
# 3. Hober Loss
# -mixture of MSE and MEA
#
# 4. Pseudo Huber Loss
# -Differentiable
