# %% [markdown]
# #  Z-Test vs T-Test in Statistics

# %% [markdown]
# ✅ Z-Test
# 🔹 Used When:
#
# Population variance (σ²) is known
#
# Sample size is large (n > 30)
#
# 🔹 Example:
# Testing whether the average height of students differs from the national average when the population standard deviation is known.

# %% [markdown]
# ✅ T-Test
# 🔹 Used When:
#
# Population variance is unknown
#
# Sample size is small (n ≤ 30)
#
# 🔹 Example:
# Testing whether a new teaching method improves scores in a class of 20 students without knowing the population standard deviation.

# %% [markdown]
# 📌 Quick Comparison
# Feature	Z-Test	T-Test
# Sample Size	> 30	≤ 30
# Population SD	Known	Unknown
# Distribution	Normal	t-distribution
