# %% [markdown]
# # Scaler Functions

# %%
🔥 Scalar Functions :
-ABS()
-ROUND()
-CEIL() & FLOOR()
-SQRT()
-LOWER()/UPPER()

🔥Scalar Functions : An SQL Scaler function is a user-defined function written in sql and it returns a single value each time it is invoked.

☑️ CEIL() - function returns the smallest integer value that is bigger than or equal to a number.

☑️Floor() - function returns the largest integer value that is smaller than or equal to a number
