# %%
🔷Day 257-DataScienceJourney(POWER BI)
 ⭐ Topic : DAX AND SQL LEETCODE SOLVED
🎸 Today , I explored :
🔥 Power Query
-Power Query : is a part of Power BI desktop ,allowing for seamless data preparation within the power BI environment
-Power Query is a data transformation and dates preparation tool allowing you to connect , clean and transform data from wide range of sources.
-It ensures that your data is ready for analysis , ensuring you to visualization and reports

*Common Errors in data :
-Missing or Null values
-Duplicate Rows
-Inconsistent data types

*UNPIVOT : transformation of data from a wide from with multiple columns to a narrow format with fewer columns by reshaping the data structure.
-It involves converting columns headers into rows values resulting in a more structured and standardized representation of the data
-The unpivot operation is useful in data analysis supporting data normalization by organizing data in a tabular format 

*PIVOT : refers to the transformation of data from a narrow format with fewer columns to a wide format with multiple columns by reorganizing the data structure.
-It enables data analyst to convert rows into columns based on specific criteria or values .
-summarizes an aggregate data , create cross tabulations and represent data in a more structure easy to underrated way for analysis and reporting
