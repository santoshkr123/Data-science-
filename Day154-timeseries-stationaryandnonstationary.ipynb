# %% [markdown]
# *Non-Stationary -If mean and variance is not constant then time series called Non Stationary
#
# *Stationary - If mean and variance is constant then time series called Stationary.
#
# ->Time Data ->Data->Transformation->Model Building[ARIMA , SARIMA , SARIMAX]
#
# *Transformation -Non-Stationary ->Stationary
# 1. first check Data is Stationary or Not
# 2. if the data is Non-Stationary then transform it to stationary
#
# *Indentify the data
# 1. Visualization
# ->trend -upward
# mean,var-Not constant -Non- Stationary
#
# 2. trend -flat
# ->mean ,var->constant->Stationary
#
# 2.Statistics Based test
# ----->ADF -Augmented Dickey Fuller
# 1.test statistics
# a.)H0->Null Hypothesis->Data is not Stationary
# b.)H1->Alternative Hypothesis-Data is Stationary
#
# 2. P value
# ->P<=0.5-Reject the Null Hypothesis
# ->P>=0.5-Accept the Null Hypothesis
#
# *Now Convert Non-Stationary to Stationary
# 1.Differencing
# D1-15-(NA)
# D2-16-(-1)
# D3-8-(8)
# D4-10-(2)
# D5-5-(5)
# D6-6-(1)
# |-Stationary Data
#
# *ACF-Auto Corr-relation Function
# Auto-Correaltion itself in the feature
# Corr-relation->To measure the relationship between two variables.
# ->ACF-means the measure the correlation between time series and its lag value
# corr(yt,yt-1) , corr(yt,yt-2) , corr(yt,yt-3)
#
# *PACF - Partial Auto Correlation Feature
# yt-2 ->yt-1->yt =>yt-1(not valid)
#
# *ARIMA-Auto Regression Integrated Moving Average
# Data-model-[ARIMA,SARIMA,SARIMAX]
# ARIMA -Auto Regression Integrated Moving Average Model
# Auto Regression-P -[0,1,2,3]-log-PACF
# Integrated -d-{o,1,2,3,n]-log-Differencing
# Moving Average Model -q[0,1,2,3,4...n]-log-ACF
#
# *Auto-Regression itself int the var
# Regression X ,y -Independent ,Y-dependent
# y=mx+x
# y=m1x1+m2x2+m3x3+......mnxn+c
# ->yt=yt-1+C
# ->yt=yt-1+yt-2+yt-3+yt-n
#
# *Integrated -Differencing
# D0=yt
# D1=yt-yt-1
# D2=yt-2-2(yt-yt-1)
# .
# .
# D2=yt-2-yt+yt-1
#
# *Moving Average -
# yt=Et-1cofft-1+Et-2cofft-2......Et-ncofft-n
#
# yt-value at time t /present time
# coff-coffieicent
# c-constant
# E-error
#
# *ARIMA - yt=yt-1cofft-1+yt-2coff-2+.....yt-ncoff-n + Et-1cofft-1+Et-2cofft-2......Et-ncofft-n
#
# *SARIMA-Season Auto Regression Integrated Moving Average(p,dq),(P,D,Q)s
# *SARIMAX-Season Auto Regression Integrated Moving Average Outlier(p,d,q),(P,D,Q)
