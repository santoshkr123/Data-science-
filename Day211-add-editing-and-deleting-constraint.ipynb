# %% [markdown]
# # ADD,EDITING,AND DELETING CONSTRAINT

# %%
🌟 ALTER TABLE customers
ADD CONSTRAINT cutomer_age_check CHECK(age > 18)

🌟AT the same time : both add column and add constraint 
ALTER TABLE customers ADD column age int not null;
ALTER TABLE customers cutomer_age_check CHECK(age > 18)
