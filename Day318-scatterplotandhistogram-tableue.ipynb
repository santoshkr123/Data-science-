# %%
🔷Day 318-DataScienceJourney(Tableau)
 ⭐ Topic : Tableau 
🎸 Today , I explored :
🔥Visualization Charts in Tableau
-Scatter Plot
:A scatter plot shows the relationship between two numerical variables. Each mark represents a data point plotted on X and Y axes.

-Histogram
:A histogram displays the distribution of a single numerical variable by grouping data into bins.
