# %%
🔷Day 320-DataScienceJourney(Tableau)
 ⭐ Topic : Tableau AND one SQL solved today!
🎸 Today , I explored :
🔥Visualization Charts in Tableau
-Reference Line
A Reference Line is a line or band added to a visualization to compare actual values against a benchmark such as:

Average

Median

Target

Constant value

Parameter or calculated field

🎯 Why Use It?

Compare performance vs target

Highlight thresholds

Provide context to trends

📊 Common Types

Line → single value (e.g., sales target)

Band → range (e.g., acceptable performance)

Distribution → quartiles, percentiles

-Bullet Graph
A Bullet Graph compares performance against a goal using:

A primary measure (actual)

A target marker

Performance ranges (good / average / poor)

It’s an efficient alternative to gauge charts.

🎯 Why Use It?

Compact & information-rich

Great for KPI dashboards

Easy comparison across categories

📊 Components of a Bullet Graph

Bar → Actual value

Line → Target value

Bands → Performance ranges
