# %% [markdown]
# # Time Intellgence Functions

# %%
🔥 Time Intelligence Functions
-SAMEPERIODLASTYEAR(dates)
-MTD(month-to-date)
-QTD(quarter-to-date)
-YTD(year-to-Date)
-DATESMTD
-PREVIOUSMONTH
-PREVIOUSQUARTER
-DATEADD
-DATESINPERIOD
DATESBETWEEN
