# %% [markdown]
# # Insert And Functions

# %%
🔥 Insert and Action Functions
-Introduction Insert And Action
-Insert Image 
-Insert Text
-Insert Shapes
-Insert Buttons
-Web URL Action
-Page Navigation Action
-Bookmark Action
-Drill Through Action
