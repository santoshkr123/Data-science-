# %% [markdown]
# # 📊Topic: Type1 and Type2 Errors , Confidence Interval and Margin of error , Point Estimate , Bayes Theorem

# %% [markdown]
# 🔯 Type1 and Type2 Errors :
# 💠 Reality- Null Hypothesis is True or Null Hypothesis is False
# 💠Decision - Null Hypothesis is True or Null Hypothesis is False
#
# 💠Outcome1 -we reject the null hypothesis when in reality it is false ->Good
# 💠Outcome2-we reject the null hypothesis, when in reality it is True->Type1 Error
# 💠Outcome3-we retain the null hypothesis, when in reality it is False->Type2 Error
# 💠Outcome4-we retain the null hypothesis, when in reality it is true->Good

# %% [markdown]
# 🔯Point Estimate -A value of any statistics , that estimates the value of an unknown population parameter is called point estimate.

# %% [markdown]
# 🔯Confidence Interval -we construct a confidence interval to help estimate what the actual value of the unknown population mean is
# Formula :
# Point of Estimate +- Margin of Error

# %% [markdown]
# 🔯Questions - On the verbal section of the CAT Exam, the standard deviation is known to be 100. A sample of 25 test takers has a mean of 250. Construct a 95% CI about the mean

# %% [markdown]
# 🔯Bayes Statistics(Bayes theorem)
# Bayesian statistics is an approach to data analysis and parameter estimation based on Bayes theorem.
#
# 🔯Probability
# 💠Independent Events-Rolling a Dice , Tossing a coin
# 💠Dependent Events - 3 Yellow ball and two red ball in bag
#
# 🔯Formula -Bayes Theorem
#  Pr (B/A)=Pr(B) * Pr(A/B)/Pr(A)
