# %% [markdown]
# 🔥 Statistical Functions
# -Average : Calculate the average of a set of numbers
# -Sum: Add all the numbers in a column
# -Count: Counts the number of rows in a table or the number of values in a column
# -Max: Returns the maximum value in a column
# -Min: Returns the minimum value in a column
# Median: Calculate the median of a set of values
#
# 🔥 Date and Time Functions
# -Year/Month/Day: Extracts the year,month,or day portion from a date
# -Date: Creates a date value
# -DateDiff: Calculate the difference between two dates
#
# 🔥Logical Functions :
# -If Function : The If function evaluates a logical expression and returns one value if the expression is true, another value if the expression is false.
#
# -AND Function : The AND Function returns True if all of its arguments are true , and False otherwise
#
# -OR Function : The OR function returns True if any of its arguments are true and False otherwise
#
# -Not Functions : The Not function negates the value of a logical expression. It returns True if the expression is false and false if the expression is True
#
# 🔥 Switch
# -The Switch function is DAX(Data Analysis Expression) is used to evaluates an expression against a list of conditions and returns a value corresponding to the first condition that evaluates to True.
# -It's similar to the switch function in other programming languages such as excel
# or sql
#
# 🔥Statistical Aggregation Function :
# ->SUMX: It iterates over each row in a table , evaluates an expression for each row , and sums up the results.
#
# ->COUNTX : It iterates over each row in a table and counts the no. of rows for which the specified expression evaluates to a non-blank value
#
# ->MIN/MAXX : It iterates over each row in a table and returns minimum/maximum value of the specified expression
#
# ->AverageX: It iterates over each row in a table and calculate the average of the specified expression
