# %% [markdown]
# # pandas

# %%
import pandas as pd
pd.read_csv('services.csv')
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
import pandas as pd
r=pd.read_csv('services.csv')
r.head()
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
r.head(3)
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
#
#                                          description  \
# 0  A walk-in center for older adults that provide...
# 1  Provides training and job placement to eligibl...
# 2  Offers supportive counseling services to San M...
#
#                                          eligibility email  ...  \
# ...

# %%
r.head(15)
# Out:
#     id  location_id  program_id accepted_payments alternate_name  \
# 0    1            1         NaN               NaN            NaN
# 1    2            2         NaN               NaN            NaN
# 2    3            3         NaN               NaN            NaN
# 3    4            4         NaN               NaN            NaN
# 4    5            5         NaN               NaN            NaN
# 5    6            6         NaN               NaN            NaN
# 6    7            7         NaN               NaN            NaN
# 7    8            8         NaN               NaN            NaN
# 8    9            9         NaN               NaN            NaN
# 9   10           10         NaN               NaN            NaN
# 10  11           11         NaN               NaN            NaN
# 11  12           12         NaN               NaN            NaN
# 12  13           13         NaN               NaN            NaN
# ...

# %%
r.tail()
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %%
r.tail(3)
# Out:
#     id  location_id  program_id         accepted_payments  \
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                application_process  \
# 20                    NaN    By phone during business hours.
# 21  Fotos para pasaportes  Walk in or apply by phone or mail
# 22                    NaN  Walk in or apply by phone or mail
#
#                                              audience  \
# 20                                                NaN
# 21  Profit and nonprofit businesses, the public, m...
# 22  Second service and nonprofit businesses, the p...
#
#                                           description eligibility  \
# 20                                just a test service         NaN
# 21  [NOTE THIS IS NOT A REAL SERVICE--THIS IS FOR ...         NaN
# ...

# %%
r.tail(15)
# Out:
#     id  location_id  program_id         accepted_payments  \
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# 15  16           16         NaN                       NaN
# 16  17           17         NaN                       NaN
# 17  18           18         NaN                       NaN
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
# ...

# %%
type(r)
# Out:
# pandas.core.frame.DataFrame

# %%
r.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
r['email']
# Out:
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
# 10                      NaN
# 11                      NaN
# 12                      NaN
# 13                      NaN
# 14                      NaN
# 15                      NaN
# 16                      NaN
# 17                      NaN
# 18                      NaN
# 19                      NaN
# 20                      NaN
# 21    passports@example.org
# 22                      NaN
# Name: email, dtype: object

# %%
type(r.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
list(r.columns)
# Out:
# ['id',
#  'location_id',
#  'program_id',
#  'accepted_payments',
#  'alternate_name',
#  'application_process',
#  'audience',
#  'description',
#  'eligibility',
#  'email',
#  'fees',
#  'funding_sources',
#  'interpretation_services',
#  'keywords',
#  'languages',
#  'name',
#  'required_documents',
#  'service_areas',
#  'status',
#  'wait_time',
#  'website',
#  'taxonomy_ids']

# %%
r['fees']
# Out:
# 0     $2.50 suggested donation for lunch for age 60 ...
# 1     None. Donations requested of clients who can a...
# 2                                                 None.
# 3     Vary according to income ($5-$90). Cash, check...
# 4         $60 application fee. Cash or checks accepted.
# 5     $55 per year membership dues. Classes have fee...
# 6     $85 per day. Vary according to income for thos...
# 7     Suggested donation of $4.25 per meal for senio...
# 8                                                 None.
# 9                                                 None.
# 10                                                None.
# 11                                                None.
# 12                                                None.
# 13                                                None.
# 14                                                None.
# 15    None for emergency services. Vary for after sc...
# 16                                                None.
# ...

# %%
r['status']
# Out:
# 0       active
# 1       active
# 2       active
# 3       active
# 4       active
# 5       active
# 6       active
# 7       active
# 8       active
# 9       active
# 10      active
# 11      active
# 12      active
# 13      active
# 14      active
# 15      active
# 16      active
# 17      active
# 18      active
# 19     defunct
# 20    inactive
# 21      active
# 22      active
# Name: status, dtype: object

# %%
type(r['status'])
# Out:
# pandas.core.series.Series

# %%
r.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
r[['id','location_id','program_id','website']]
# Out:
#     id  location_id  program_id                 website
# 0    1            1         NaN                     NaN
# 1    2            2         NaN                     NaN
# 2    3            3         NaN                     NaN
# 3    4            4         NaN                     NaN
# 4    5            5         NaN                     NaN
# 5    6            6         NaN                     NaN
# 6    7            7         NaN                     NaN
# 7    8            8         NaN                     NaN
# 8    9            9         NaN                     NaN
# 9   10           10         NaN                     NaN
# 10  11           11         NaN                     NaN
# 11  12           12         NaN                     NaN
# 12  13           13         NaN                     NaN
# 13  14           14         NaN                     NaN
# 14  15           15         NaN                     NaN
# 15  16           16         NaN                     NaN
# ...

# %%
r.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %% [markdown]
# # now reading excel file in pandas

# %%
import pandas as pd
pd.read_excel("LUSID Excel - Setting up your market data (1).xlsx")
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0          NaN         NaN         NaN
# 1          NaN         NaN         NaN
# 2          NaN         NaN         NaN
# 3          NaN         NaN         NaN
# 4          NaN         NaN         NaN
# 5          NaN         NaN         NaN
# 6          NaN         NaN         NaN
# 7          NaN         NaN         NaN
# 8          NaN         NaN         NaN
# 9          NaN         NaN         NaN
# 10         NaN         NaN         NaN
# 11         NaN         NaN         NaN
# 12         NaN         NaN         NaN
# 13         NaN         NaN         NaN
# 14         NaN         NaN         NaN
# 15         NaN         NaN         NaN
# 16         NaN         NaN         NaN
# 17         NaN         NaN         NaN
# 18         NaN         NaN         NaN
# 19         NaN         NaN         NaN
# 20         NaN         NaN         NaN
# 21         NaN         NaN         NaN
# 22         NaN         NaN         NaN
# ...

# %%
import pandas as pd
r1=pd.read_excel("LUSID Excel - Setting up your market data (1).xlsx")
type(r1)
# Out:
# pandas.core.frame.DataFrame

# %%
r1.dtypes
# Out:
# Unnamed: 0    float64
# Unnamed: 1    float64
# Unnamed: 2    float64
# Unnamed: 3     object
# Unnamed: 4     object
# Unnamed: 5     object
# Unnamed: 6    float64
# Unnamed: 7     object
# Unnamed: 8     object
# Unnamed: 9     object
# dtype: object

# %%
r1.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
r1['Unnamed: 7']
# Out:
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11    LUSID also accepts UTC, UTS offsets and cutlabels
# 12                                                  NaN
# 13                                   Additional formats
# 14                                                  NaN
# 15                              Standard UTC timestamp:
# 16                                                  NaN
# ...

# %%
r1[[ 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3']]
# Out:
#     Unnamed: 1  Unnamed: 2                                         Unnamed: 3
# 0          NaN         NaN                                                NaN
# 1          NaN         NaN                                 Datetimes in LUSID
# 2          NaN         NaN                                                NaN
# 3          NaN         NaN   This sheet allows you to format datetimes for...
# 4          NaN         NaN        If you have any questions please visit our:
# 5          NaN         NaN                                                NaN
# 6          NaN         NaN                                                NaN
# 7          NaN         NaN                                                NaN
# 8          NaN         NaN                                                NaN
# 9          NaN         NaN                                                NaN
# 10         NaN         NaN                                                NaN
# ...

# %%
r1.head()
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN
#
#                                           Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                                                NaN        NaN        NaN
# 1                                 Datetimes in LUSID        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3   This sheet allows you to format datetimes for...        NaN        NaN
# 4        If you have any questions please visit our:        NaN        NaN
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0         NaN        NaN        NaN        NaN
# 1         NaN        NaN        NaN        NaN
# 2         NaN        NaN        NaN        NaN
# 3         NaN        NaN        NaN        NaN
# ...

# %%
r1.tail()
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2 Unnamed: 3  \
# 23         NaN         NaN         NaN        NaN
# 24         NaN         NaN         NaN        NaN
# 25         NaN         NaN         NaN        NaN
# 26         NaN         NaN         NaN        NaN
# 27         NaN         NaN         NaN        NaN
#
#                                           Unnamed: 4  \
# 23  Although the date can still appears without time
# 24                                               NaN
# 25                      Add an hour to your datetime
# 26                                               NaN
# 27              Subtract a minute from your datetime
#
#                     Unnamed: 5  Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 23  2019-04-10 13:30:45.550000         NaN        NaN        NaN        NaN
# 24                         NaN         NaN        NaN        NaN        NaN
# 25  2019-04-10 14:30:45.550000         NaN        NaN        NaN        NaN
# ...

# %%
import pandas as pd
pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import pandas as pd
r2=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv')
r2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
r2.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
type(r2.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
r2['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
type(r2['Survived'])
# Out:
# pandas.core.series.Series

# %%
r2[['Survived', 'Pclass', 'Name']]
# Out:
#      Survived  Pclass                                               Name
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
# [891 rows x 3 columns]

# %%
r2['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
import pandas as pd
pd.read_html('https://www.basketball-reference.com/leagues/NBA_2025.html')
# Out:
# [          Eastern Conference   W   L   W/L%    GB   PS/G   PA/G    SRS
#  0   Cleveland Cavaliers* (1)  64  18  0.780     —  121.9  112.4   8.81
#  1        Boston Celtics* (2)  61  21  0.744   3.0  116.3  107.2   8.28
#  2       New York Knicks* (3)  51  31  0.622  13.0  115.8  111.7   3.59
#  3        Indiana Pacers* (4)  50  32  0.610  14.0  117.4  115.1   1.68
#  4       Milwaukee Bucks* (5)  48  34  0.585  16.0  115.5  113.0   2.12
#  5       Detroit Pistons* (6)  44  38  0.537  20.0  115.5  113.6   1.73
#  6         Orlando Magic* (7)  41  41  0.500  23.0  105.4  105.5  -0.70
#  7         Atlanta Hawks* (8)  40  42  0.488  24.0  118.2  119.3  -1.41
#  8         Chicago Bulls* (9)  39  43  0.476  25.0  117.8  119.4  -1.83
#  9           Miami Heat* (10)  37  45  0.451  27.0  110.6  110.0   0.11
#  10      Toronto Raptors (11)  30  52  0.366  34.0  110.9  115.2  -4.40
#  11        Brooklyn Nets (12)  26  56  0.317  38.0  105.1  112.2  -6.95
# ...

# %%
import pandas as pd
r3=pd.read_html('https://www.basketball-reference.com/leagues/NBA_2025.html')
type(r3)
# Out:
# list

# %%
len(r3)
# Out:
# 13

# %%
data1=r3[0]
data1
# Out:
#           Eastern Conference   W   L   W/L%    GB   PS/G   PA/G    SRS
# 0   Cleveland Cavaliers* (1)  64  18  0.780     —  121.9  112.4   8.81
# 1        Boston Celtics* (2)  61  21  0.744   3.0  116.3  107.2   8.28
# 2       New York Knicks* (3)  51  31  0.622  13.0  115.8  111.7   3.59
# 3        Indiana Pacers* (4)  50  32  0.610  14.0  117.4  115.1   1.68
# 4       Milwaukee Bucks* (5)  48  34  0.585  16.0  115.5  113.0   2.12
# 5       Detroit Pistons* (6)  44  38  0.537  20.0  115.5  113.6   1.73
# 6         Orlando Magic* (7)  41  41  0.500  23.0  105.4  105.5  -0.70
# 7         Atlanta Hawks* (8)  40  42  0.488  24.0  118.2  119.3  -1.41
# 8         Chicago Bulls* (9)  39  43  0.476  25.0  117.8  119.4  -1.83
# 9           Miami Heat* (10)  37  45  0.451  27.0  110.6  110.0   0.11
# 10      Toronto Raptors (11)  30  52  0.366  34.0  110.9  115.2  -4.40
# 11        Brooklyn Nets (12)  26  56  0.317  38.0  105.1  112.2  -6.95
# ...

# %%
data1.head()
# Out:
#          Eastern Conference   W   L   W/L%    GB   PS/G   PA/G   SRS
# 0  Cleveland Cavaliers* (1)  64  18  0.780     —  121.9  112.4  8.81
# 1       Boston Celtics* (2)  61  21  0.744   3.0  116.3  107.2  8.28
# 2      New York Knicks* (3)  51  31  0.622  13.0  115.8  111.7  3.59
# 3       Indiana Pacers* (4)  50  32  0.610  14.0  117.4  115.1  1.68
# 4      Milwaukee Bucks* (5)  48  34  0.585  16.0  115.5  113.0  2.12

# %%
data1.tail()
# Out:
#          Eastern Conference   W   L   W/L%    GB   PS/G   PA/G    SRS
# 10     Toronto Raptors (11)  30  52  0.366  34.0  110.9  115.2  -4.40
# 11       Brooklyn Nets (12)  26  56  0.317  38.0  105.1  112.2  -6.95
# 12  Philadelphia 76ers (13)  24  58  0.293  40.0  109.6  115.8  -6.29
# 13   Charlotte Hornets (14)  19  63  0.232  45.0  105.1  114.2  -9.10
# 14  Washington Wizards (15)  18  64  0.220  46.0  108.0  120.4 -12.14

# %%
data1.columns
# Out:
# Index(['Eastern Conference', 'W', 'L', 'W/L%', 'GB', 'PS/G', 'PA/G', 'SRS'], dtype='object')

# %%
type(data1.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
data1.dtypes
# Out:
# Eastern Conference     object
# W                       int64
# L                       int64
# W/L%                  float64
# GB                     object
# PS/G                  float64
# PA/G                  float64
# SRS                   float64
# dtype: object

# %%
data1['W']
# Out:
# 0     64
# 1     61
# 2     51
# 3     50
# 4     48
# 5     44
# 6     41
# 7     40
# 8     39
# 9     37
# 10    30
# 11    26
# 12    24
# 13    19
# 14    18
# Name: W, dtype: int64

# %%
data1[['W','L']]
# Out:
#      W   L
# 0   64  18
# 1   61  21
# 2   51  31
# 3   50  32
# 4   48  34
# 5   44  38
# 6   41  41
# 7   40  42
# 8   39  43
# 9   37  45
# 10  30  52
# 11  26  56
# 12  24  58
# 13  19  63
# 14  18  64
