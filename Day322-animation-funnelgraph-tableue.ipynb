# %%
🔷Day 322-DataScienceJourney(Tableau)
 ⭐ Topic : Tableau AND one SQL solved today!
🎸 Today , I explored :
🔥Visualization Charts in Tableau
-funnel graph
A Funnel Chart shows how values decrease through stages (e.g., Sales Pipeline, Conversion Rates).

📌 Common Use Cases

Sales pipeline (Leads → Opportunities → Deals)

Website conversion (Visits → Signups → Purchases)

Process drop-offs

🛠 How to Create a Funnel Chart (Standard Method)

Method: Using Bar Chart + Table Calculation

Prepare your data

One dimension: Stage (e.g., Lead, Qualified, Closed)

One measure: Count / Value

Create a Bar Chart

Drag Stage → Rows

Drag Measure → Columns

Sort stages from largest to smallest

Create Funnel Shape

Drag the same Measure again → Columns

Right-click the second measure → Dual Axis

Synchronize axes

Apply Table Calculation

On the second measure → Quick Table Calculation

Choose Percent of Total

Compute using Stage

Format

Change bar size (Marks → Size)

Hide axis headers

Add labels (percent or values)

🎯 Alternative Funnel Method

Use Polygon marks for more advanced, true funnel shapes
                 
-animation graph
Animation helps visualize changes over time smoothly.

📌 Common Use Cases

Sales growth over time

KPI trends

Market share changes

Moving scatter plots

🛠 Enable Animation in Tableau

Go to Format → Animations

Set:

Workbook: ON

Duration: 0.5–1.0 seconds

Style: Simultaneous or Sequential

📊 Example Animation Graphs
🔹 Animated Line Chart

Drag Date → Columns

Drag Sales → Rows

Enable Animations

As filters or parameters change, the line animates automatically

🔹 Animated Bar Chart (Racing Bars)

Category → Rows

Sales → Columns

Date → Pages shelf

Click Play ▶️

Turn on Animations for smooth transitions

🔹 Animated Scatter Plot

Sales → Columns

Profit → Rows

Category → Color

Date → Pages

Enable animations for motion effect
