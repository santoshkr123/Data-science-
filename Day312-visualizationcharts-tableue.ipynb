# %%
🔷Day 312-DataScienceJourney(Tableau)
 ⭐ Topic : Tableau
🎸 Today , I explored :
🔥Visualization Charts in Tableau
-Bar chart
🔥 1. Bar Chart

Purpose: Compare values across categories

📊 When to Use

Comparing sales by region

Showing profit by product category

Ranking items (top/bottom performers)

🛠 How to Create in Tableau

Drag Dimension (e.g., Category) → Columns

Drag Measure (e.g., Sales) → Rows

Marks card → Bar

Sort for better comparison

✅ Best Practices

Keep bars horizontal if labels are long

Start axis at zero

Limit categories (avoid clutter)


🔥 2. Pie Chart

Purpose: Show proportions or percentage contribution

📊 When to Use

Market share

Sales contribution by category

Simple part-to-whole comparisons

🛠 How to Create in Tableau

Marks card → Pie

Drag Measure (Sales) → Angle

Drag Dimension (Category) → Color

Add labels → Percentage of Total

⚠️ Limitations

Hard to compare slices accurately

Avoid using when categories > 5

🔥 3. Stacked Bar Chart

Purpose: Compare totals and see composition

📊 When to Use

Sales by region broken down by category

Revenue by year and product type

Sub-category contribution within totals

🛠 How to Create in Tableau

Drag Dimension (Region) → Columns

Drag Measure (Sales) → Rows

Drag another Dimension (Category) → Color

Ensure Analysis → Stack Marks → On

✅ Best Practices

Use consistent colors

Limit stacks to maintain readability

Use tooltips for detailed insights


📌 Quick Comparison
Chart Type	Best For	Avoid When
Bar Chart	Comparison	Too many categories
Pie Chart	Proportions	Many slices
Stacked Bar	Composition + Total	Too many segments
