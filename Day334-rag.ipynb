# %%
Retrieval-Augmented Generation (RAG) : 
Retrieval-Augmented Generation (RAG) is an AI framework that combines the power of large language models (LLMs) with external information retrieval systems. In essence, RAG allows generative AI models to access, process, and incorporate up-to-date and relevant information from authoritative sources before generating a response. This overcomes some of the inherent limitations of LLMs, which are typically trained on a fixed dataset and can, therefore, lack knowledge of recent events or specific domain-specific information. 

RAG is a technique that combines two components: 
• Retriever: Finds relevant documents from a database or vector store. 
• Generator: Uses an LLM to answer questions based on those documents.
