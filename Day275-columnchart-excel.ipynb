# %%
🔷Day 275-DataScienceJourney(EXCEL)
 ⭐ Topic : Excel AND one SQL solved today!
🎸 Today , I explored :
🔥Creating an Excel Column Chart
-Create Column
-Design Ribbon
-Modifying and Data on Excel Chart
-Formatting Chart
