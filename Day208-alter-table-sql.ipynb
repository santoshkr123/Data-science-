# %% [markdown]
# # Alter Table

# %%
🌟 ADD Columns in Alter table

1. ALTER TABLE customer
 ADD Column password VARCHAR(255) Not Null After name;

2. ALTER TABLE Customer
ADD Column surname VARCHAR(255) AFTER NAME;

3. ALTER TABLE Customer
ADD Column rollno VARCHAR(255) AFTER name
ADD COLUMN regdate DATETIME NOT NULL DEFAULT CURRENT_TIMESTAMP
