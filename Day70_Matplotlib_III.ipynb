# %% [markdown]
# # Histogram plot in matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

x=np.random.randint(10,60,(50))
print(x)
# Out:
# [35 23 17 14 36 53 16 12 10 57 46 36 51 19 32 35 28 11 29 57 41 55 17 17
#  36 31 58 43 32 52 15 58 19 12 37 36 25 55 10 46 40 30 27 12 17 22 26 45
#  20 41]

# %%
no=[35, 23, 17, 14, 36, 53, 16, 12, 10, 57, 46, 36, 51, 19, 32,
    35, 28, 11, 29, 57, 41, 55, 17, 17, 36, 31, 58, 43, 32, 52, 
    15, 58, 19, 12, 37, 36, 25, 55, 10, 46, 40, 30, 27, 12, 17, 22, 26, 45, 20, 41]

plt.hist(no)
# Out:
# (array([7., 8., 3., 5., 4., 7., 4., 3., 3., 6.]),
#  array([10. , 14.8, 19.6, 24.4, 29.2, 34. , 38.8, 43.6, 48.4, 53.2, 58. ]),
#  <BarContainer object of 10 artists>)

# %%
no=[35, 23, 17, 14, 36, 53, 16, 12, 10, 57, 46, 36, 51, 19, 32,
    35, 28, 11, 29, 57, 41, 55, 17, 17, 36, 31, 58, 43, 32, 52, 
    15, 58, 19, 12, 37, 36, 25, 55, 10, 46, 40, 30, 27, 12, 17, 22, 26, 45, 20, 41]

plt.title("Record")
plt.hist(no)
# Out:
# (array([7., 8., 3., 5., 4., 7., 4., 3., 3., 6.]),
#  array([10. , 14.8, 19.6, 24.4, 29.2, 34. , 38.8, 43.6, 48.4, 53.2, 58. ]),
#  <BarContainer object of 10 artists>)

# %%
no=[35, 23, 17, 14, 36, 53, 16, 12, 10, 57, 46, 36, 51, 19, 32,
    35, 28, 11, 29, 57, 41, 55, 17, 17, 36, 31, 58, 43, 32, 52, 
    15, 58, 19, 12, 37, 36, 25, 55, 10, 46, 40, 30, 27, 12, 17, 22, 26, 45, 20, 41]

plt.title("Record")
plt.xlabel("Python")
plt.ylabel("Number")
plt.hist(no)
# Out:
# (array([7., 8., 3., 5., 4., 7., 4., 3., 3., 6.]),
#  array([10. , 14.8, 19.6, 24.4, 29.2, 34. , 38.8, 43.6, 48.4, 53.2, 58. ]),
#  <BarContainer object of 10 artists>)

# %%
no=[35, 23, 17, 14, 36, 53, 16, 12, 10, 57, 46, 36, 51, 19, 32,
    35, 28, 11, 29, 57, 41, 55, 17, 17, 36, 31, 58, 43, 32, 52, 
    15, 58, 19, 12, 37, 36, 25, 55, 10, 46, 40, 30, 27, 12, 17, 22, 26, 45, 20, 41]

plt.title("Record")
plt.xlabel("Python")
plt.ylabel("Number")

plt.hist(no,color="green")
# Out:
# (array([7., 8., 3., 5., 4., 7., 4., 3., 3., 6.]),
#  array([10. , 14.8, 19.6, 24.4, 29.2, 34. , 38.8, 43.6, 48.4, 53.2, 58. ]),
#  <BarContainer object of 10 artists>)

# %%
no=[35, 23, 17, 14, 36, 53, 16, 12, 10, 57, 46, 36, 51, 19, 32,
    35, 28, 11, 29, 57, 41, 55, 17, 17, 36, 31, 58, 43, 32, 52, 
    15, 58, 19, 12, 37, 36, 25, 55, 10, 46, 40, 30, 27, 12, 17, 22, 26, 45, 20, 41]

plt.title("Record")
plt.xlabel("Python")
plt.ylabel("Number")

plt.hist(no,color="green",edgecolor="yellow")
plt.show()

# %%
no=[35, 23, 17, 14, 36, 53, 16, 12, 10, 57, 46, 36, 51, 19, 32,
    35, 28, 11, 29, 57, 41, 55, 17, 17, 36, 31, 58, 43, 32, 52, 
    15, 58, 19, 12, 37, 36, 25, 55, 10, 46, 40, 30, 27, 12, 17, 22, 26, 45, 20, 41]

plt.title("Record")
plt.xlabel("Python")
plt.ylabel("Number")

l=[10,20,30,40,50,60]
plt.hist(no,color="green",edgecolor="yellow",bins=l)
plt.show()

# %%
no=[35, 23, 17, 14, 36, 53, 16, 12, 10, 57, 46, 36, 51, 19, 32,
    35, 28, 11, 29, 57, 41, 55, 17, 17, 36, 31, 58, 43, 32, 52, 
    15, 58, 19, 12, 37, 36, 25, 55, 10, 46, 40, 30, 27, 12, 17, 22, 26, 45, 20, 41]

plt.title("Record")
plt.xlabel("Python")
plt.ylabel("Number")

plt.hist(no,"auto",(0,100))
plt.show()

# %%
no=[35, 23, 17, 14, 36, 53, 16, 12, 10, 57, 46, 36, 51, 19, 32,
    35, 28, 11, 29, 57, 41, 55, 17, 17, 36, 31, 58, 43, 32, 52, 
    15, 58, 19, 12, 37, 36, 25, 55, 10, 46, 40, 30, 27, 12, 17, 22, 26, 45, 20, 41]

plt.title("Record")
plt.xlabel("Python")
plt.ylabel("Number")

plt.hist(no,edgecolor="yellow",cumulative=-1)
plt.show()

# %%
no=[35, 23, 17, 14, 36, 53, 16, 12, 10, 57, 46, 36, 51, 19, 32,
    35, 28, 11, 29, 57, 41, 55, 17, 17, 36, 31, 58, 43, 32, 52, 
    15, 58, 19, 12, 37, 36, 25, 55, 10, 46, 40, 30, 27, 12, 17, 22, 26, 45, 20, 41]

plt.title("Record")
plt.xlabel("Python")
plt.ylabel("Number")

plt.hist(no,edgecolor="yellow",bottom=10)
plt.show()

# %%
no=[35, 23, 17, 14, 36, 53, 16, 12, 10, 57, 46, 36, 51, 19, 32,
    35, 28, 11, 29, 57, 41, 55, 17, 17, 36, 31, 58, 43, 32, 52, 
    15, 58, 19, 12, 37, 36, 25, 55, 10, 46, 40, 30, 27, 12, 17, 22, 26, 45, 20, 41]

plt.title("Record")
plt.xlabel("Python")
plt.ylabel("Number")

plt.hist(no,edgecolor="yellow",bottom=20)
plt.show()

# %%
no=[35, 23, 17, 14, 36, 53, 16, 12, 10, 57, 46, 36, 51, 19, 32,
    35, 28, 11, 29, 57, 41, 55, 17, 17, 36, 31, 58, 43, 32, 52, 
    15, 58, 19, 12, 37, 36, 25, 55, 10, 46, 40, 30, 27, 12, 17, 22, 26, 45, 20, 41]

plt.title("Record")
plt.xlabel("Python")
plt.ylabel("Number")

plt.hist(no,edgecolor="yellow",align="left")
plt.show()

# %%
no=[35, 23, 17, 14, 36, 53, 16, 12, 10, 57, 46, 36, 51, 19, 32,
    35, 28, 11, 29, 57, 41, 55, 17, 17, 36, 31, 58, 43, 32, 52, 
    15, 58, 19, 12, 37, 36, 25, 55, 10, 46, 40, 30, 27, 12, 17, 22, 26, 45, 20, 41]

plt.title("Record")
plt.xlabel("Python")
plt.ylabel("Number")

plt.hist(no,edgecolor="yellow",align="right")
plt.show()

# %%
no=[35, 23, 17, 14, 36, 53, 16, 12, 10, 57, 46, 36, 51, 19, 32,
    35, 28, 11, 29, 57, 41, 55, 17, 17, 36, 31, 58, 43, 32, 52, 
    15, 58, 19, 12, 37, 36, 25, 55, 10, 46, 40, 30, 27, 12, 17, 22, 26, 45, 20, 41]

plt.title("Record")
plt.xlabel("Python")
plt.ylabel("Number")

plt.hist(no,edgecolor="yellow",align="mid")
plt.show()

# %%
no=[35, 23, 17, 14, 36, 53, 16, 12, 10, 57, 46, 36, 51, 19, 32,
    35, 28, 11, 29, 57, 41, 55, 17, 17, 36, 31, 58, 43, 32, 52, 
    15, 58, 19, 12, 37, 36, 25, 55, 10, 46, 40, 30, 27, 12, 17, 22, 26, 45, 20, 41]

plt.title("Record")
plt.xlabel("Python")
plt.ylabel("Number")

plt.hist(no,edgecolor="green",histtype="step")
plt.show()

# %%
no=[35, 23, 17, 14, 36, 53, 16, 12, 10, 57, 46, 36, 51, 19, 32,
    35, 28, 11, 29, 57, 41, 55, 17, 17, 36, 31, 58, 43, 32, 52, 
    15, 58, 19, 12, 37, 36, 25, 55, 10, 46, 40, 30, 27, 12, 17, 22, 26, 45, 20, 41]

plt.title("Record")
plt.xlabel("Python")
plt.ylabel("Number")

plt.hist(no,color="yellow",edgecolor="green",histtype="stepfilled")
plt.show()

# %%
no=[35, 23, 17, 14, 36, 53, 16, 12, 10, 57, 46, 36, 51, 19, 32,
    35, 28, 11, 29, 57, 41, 55, 17, 17, 36, 31, 58, 43, 32, 52, 
    15, 58, 19, 12, 37, 36, 25, 55, 10, 46, 40, 30, 27, 12, 17, 22, 26, 45, 20, 41]

plt.title("Record")
plt.xlabel("Python")
plt.ylabel("Number")

plt.hist(no,color="yellow",edgecolor="green",histtype="barstacked")
plt.show()

# %%
no=[35, 23, 17, 14, 36, 53, 16, 12, 10, 57, 46, 36, 51, 19, 32,
    35, 28, 11, 29, 57, 41, 55, 17, 17, 36, 31, 58, 43, 32, 52, 
    15, 58, 19, 12, 37, 36, 25, 55, 10, 46, 40, 30, 27, 12, 17, 22, 26, 45, 20, 41]

plt.title("Record")
plt.xlabel("Python")
plt.ylabel("Number")

plt.hist(no,color="yellow",edgecolor="green",histtype="barstacked",orientation="horizontal")
plt.show()

# %%
no=[35, 23, 17, 14, 36, 53, 16, 12, 10, 57, 46, 36, 51, 19, 32,
    35, 28, 11, 29, 57, 41, 55, 17, 17, 36, 31, 58, 43, 32, 52, 
    15, 58, 19, 12, 37, 36, 25, 55, 10, 46, 40, 30, 27, 12, 17, 22, 26, 45, 20, 41]

plt.title("Record")
plt.xlabel("Python")
plt.ylabel("Number")

plt.hist(no,color="yellow",edgecolor="green",histtype="barstacked",orientation="vertical")
plt.show()

# %%
no=[35, 23, 17, 14, 36, 53, 16, 12, 10, 57, 46, 36, 51, 19, 32,
    35, 28, 11, 29, 57, 41, 55, 17, 17, 36, 31, 58, 43, 32, 52, 
    15, 58, 19, 12, 37, 36, 25, 55, 10, 46, 40, 30, 27, 12, 17, 22, 26, 45, 20, 41]

plt.title("Record")
plt.xlabel("Python")
plt.ylabel("Number")

plt.hist(no,color="yellow",edgecolor="green",histtype="barstacked",rwidth=0.6)
plt.show()

# %%
no=[35, 23, 17, 14, 36, 53, 16, 12, 10, 57, 46, 36, 51, 19, 32,
    35, 28, 11, 29, 57, 41, 55, 17, 17, 36, 31, 58, 43, 32, 52, 
    15, 58, 19, 12, 37, 36, 25, 55, 10, 46, 40, 30, 27, 12, 17, 22, 26, 45, 20, 41]

plt.title("Record")
plt.xlabel("Python")
plt.ylabel("Number")

plt.hist(no,color="yellow",edgecolor="green",histtype="barstacked",log=True)
plt.show()

# %%
no=[35, 23, 17, 14, 36, 53, 16, 12, 10, 57, 46, 36, 51, 19, 32,
    35, 28, 11, 29, 57, 41, 55, 17, 17, 36, 31, 58, 43, 32, 52, 
    15, 58, 19, 12, 37, 36, 25, 55, 10, 46, 40, 30, 27, 12, 17, 22, 26, 45, 20, 41]

plt.title("Record")
plt.xlabel("Python")
plt.ylabel("Number")

plt.hist(no,color="yellow",edgecolor="green",label="code")
plt.legend()
plt.show()

# %%
no=[35, 23, 17, 14, 36, 53, 16, 12, 10, 57, 46, 36, 51, 19, 32,
    35, 28, 11, 29, 57, 41, 55, 17, 17, 36, 31, 58, 43, 32, 52, 
    15, 58, 19, 12, 37, 36, 25, 55, 10, 46, 40, 30, 27, 12, 17, 22, 26, 45, 20, 41]

plt.title("Record")
plt.xlabel("Python")
plt.ylabel("Number")

plt.hist(no,color="yellow",edgecolor="green",label="code")
plt.legend()
plt.axvline(45,color="magenta")
plt.show()

# %%
no=[35, 23, 17, 14, 36, 53, 16, 12, 10, 57, 46, 36, 51, 19, 32,
    35, 28, 11, 29, 57, 41, 55, 17, 17, 36, 31, 58, 43, 32, 52, 
    15, 58, 19, 12, 37, 36, 25, 55, 10, 46, 40, 30, 27, 12, 17, 22, 26, 45, 20, 41]

plt.title("Record")
plt.xlabel("Python")
plt.ylabel("Number")

plt.hist(no,color="yellow",edgecolor="green",label="code")
plt.legend()
plt.axvline(45,color="magenta",label="separate")
plt.legend()
plt.show()

# %%
no=[35, 23, 17, 14, 36, 53, 16, 12, 10, 57, 46, 36, 51, 19, 32,
    35, 28, 11, 29, 57, 41, 55, 17, 17, 36, 31, 58, 43, 32, 52, 
    15, 58, 19, 12, 37, 36, 25, 55, 10, 46, 40, 30, 27, 12, 17, 22, 26, 45, 20, 41]

plt.title("Record")
plt.xlabel("Python")
plt.ylabel("Number")

plt.hist(no,color="yellow",edgecolor="green",label="code")
plt.legend()
plt.axvline(45,color="magenta",label="separate")
plt.legend()
plt.grid()
plt.show()
