# %% [markdown]
# # 🔷Using XAMPP server , solved two methods ,by GUI and SQL

# %% [markdown]
# *client requirements:
# 1.Database Name : IHH_College
# 2.Student Registration Details :
# Student Name|Email Id|Mobile Number|Create Password
# 3.Student Login Details: Mobile Number|Password|Student ID.

# %% [markdown]
# create Database ihh_college;
# create table st_details;
# select*from st_details;
# insert into st_details(st_id,st_name,st_email,st_mob,st_pass)values(1,'santosh kumar','santoshtech@123',7965665656,123477)
