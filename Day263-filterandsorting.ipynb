# %% [markdown]
# # Filter and Sorting

# %%
🔥Filter and Sorting :
-Explore Data Tab and use filter
-Sort column
-Smallest to Largest
-Largest to Smallest

🔥SQL Practice :
-user-activity-for-the-past-30-days-i
