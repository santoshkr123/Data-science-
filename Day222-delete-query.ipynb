# %% [markdown]
# # DELETE QUERY

# %%
⭐ DELETE QUERY
-DELETE QUERY to delete row(s)
-DELETE based on multiple conditions 

✨ Order Execution order in sql
-FROM
-JOIN
-WHERE
-GROUP BY
-HAVING
-SELECT
-DISTINCT
-ORDER

✨What the query look like :
SELECT
FROM 
WHERE
GROUP BY
HAVING
ORDER BY 
LIMIT



Delete from table_name
where condition;
