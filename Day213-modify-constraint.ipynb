# %% [markdown]
# # edit Problems in MYSQL , DROP Constrainst

# %%
🌟Edit Problems in MySQL , Drop Constraints
🌟 ALTER TABLE customers
ADD CONSTRAINT cutomer_age_check CHECK(age > 18)

ALTER TABLE customers
MODIFY CONSTRAINT customer_age_check CHECK(age > 18);

Note : The columns definition for a constraint cannot be modified e.g : 
add new columns ,drop existing columns or change the order of columns .
To make these types of changes , the constraint must be dropped and recreated.
