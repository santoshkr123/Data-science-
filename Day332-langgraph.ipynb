# %% [markdown]
# LangGraph is a framework for building stateful, multi-step AI workflows using graphs. Think:
#
# Nodes = functions / LLM calls / tools
#
# Edges = control flow
#
# State = shared memory that moves through the graph
#
# It’s especially good for:
#
# 🤖 Multi-agent systems
#
# 🔁 Loops & conditional logic (retry, reflect, decide)
#
# 🧠 Long-running workflows with memory
#
# 🛠️ Tool-using agents that aren’t just linear chains
#
# Why people use it instead of plain LangChain chains
#
# Chains are linear → A → B → C
#
# LangGraph lets you do → A → B → (if X then C else D) → loop → end
#
# Much easier to reason about complex agent behavior
#
# Tiny mental model
#
# LangChain = pipelines
# LangGraph = flowcharts with memory
# Example: Agent that decides → acts → reflects → maybe retries
# What this graph does
#
# User asks a question
#
# Agent answers
#
# Agent checks its own answer
#
# If bad → retry
#
# If good → finish
#
# That loop is where LangGraph shines.
