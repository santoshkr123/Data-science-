# %% [markdown]
# # DDL -Truncate | Drop

# %% [markdown]
# 🌟 DDL commands for Table : Create | Truncate | Drop
# Create Database ihh_college;
# Create Table st_details(
# st_id integer(11),
# st_name varchar(255),
# st_mob varchar(255),
# st_city varchar(255)
# );
#
# 🌟How to truncate table ?
# ->Truncate Table st_details
#
# Difference between Truncate and Drop ?

# %% [markdown]
# Truncate : It is used to delete all the records from the table permanently
# Drop : This statement is used to delete the objects i,e Tables from the database along with table structure
