# %%
CREATE EXPRESSION USING SELECT
CONSTANTS VALUE USING SELECT
CONSTANT VALUE USING SELECT

⭐ Solve the Mathematical Expression and find the PPI(Pixel Per Inch) value the help of mobile Resolution width , Height , and Screen Size

✨ select model , rating/10 
from smartphones_cleaned_v6;

✨ select model , resolution_width * resolution_width
from smartphones_cleaned_v6;

✨select model , resolution_width * resolution_width + resolution_height * resolution_height) 
smartphones_cleaned_v6;

✨select model , 
sqrt(resolution_width * resolution_width + resolution_height * resolution_height)


✨select model , 
sqrt(resolution_width * resolution_width + resolution_height * resolution_height)/screen_size as PPI
from smartphones_cleaned_v6;

✨select model , 'featurephone' AS 'mobile_type
from smartphones_cleaned_v6;
