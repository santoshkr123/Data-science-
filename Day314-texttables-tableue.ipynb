# %%
🔷Day 314-DataScienceJourney(Tableau)
 ⭐ Topic : Tableau 
🎸 Today , I explored
📌 What is a Text Table?

A Text Table (also called a Crosstab) in Tableau displays data in rows and columns using text values only—no bars, lines, or shapes. It’s similar to an Excel pivot table.

🧱 Key Components

Rows & Columns: Dimensions (e.g., Region, Category, Date)

Text (Marks Card): Measures (e.g., Sales, Profit, Quantity)

Aggregation: SUM, AVG, COUNT, etc.

✅ When to Use Text Tables

Exact number comparison is required

Reporting and auditing purposes

Financial statements or KPI summaries

When visual encoding might hide precise values

🛠️ How to Create a Text Table in Tableau

Drag Dimensions to Rows and/or Columns

Drag a Measure to the Text mark

Tableau automatically creates a text table

Format (font, alignment, gridlines) as needed

🎯 Advantages

Easy to read exact values

Familiar, spreadsheet-like format

Great for detailed data inspection
