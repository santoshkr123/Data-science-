# %% [markdown]
# Deep Learning :
# ->The roots of machine learning can be traced back to the 1950s and 1960s.
# ->Perceptrons and Early Developments 1960s
# ->First AI Winter 1970s-1980s
#
# *Artificial Intelligence : Ability of machine to imitate human intelligence
# *Machine Learning : Algorithms to incorporate intelligence into machine by automatically learning from data
# *Deep Learning : Algorithms that mimics human brain to incorporate intelligence into machine.
#
# Machine Learning
# FE-Feature Engineering-
# (Domain Knowledge)
# DATA increases -------
# performance also increase
# Unable to identify complex patterns
#
# Deep Learning
#  FE-Automatic -F S
# -Data increase ,performances also increases but better than machine learning model ,performance also increase(DL)
# --DL adapt to identify complex Non Linear patterns
#
# *Need Of Deep Learning
# -To solve complex problem
# -Hardware document
#
# *Uses Cases Of Deep Learning
# -Youtube Recommendation
# -Google Translate
# -FaceID -Images Recognition
# -SIRI
# -ChatGPT
#
# *Types -Approaches
# 1. Artificial Neural Network(ANN)
# -Tabular Data
# -Fraud Detection
# -Price Optimization
#
# 2. CNN(Convolutional Neural Network)
# -Images
# -Object Detection
# -Fraud Reconition
# -Stable Diffuision
# -Traffic Notation
#
# 3. Recurrent Neural Network
# -To address sequential Data
# -Text(Running Text)
# -Videos / Speeches
# -Trading data(stock data)
# -Language Modelling
# -Forecast -Cryptocoin
# -Transformer
#
# 4. Graphical Neural Network(GNN)
# -Social Media like Facebook
