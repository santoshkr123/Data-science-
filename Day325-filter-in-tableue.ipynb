# %%
🔷Day 325-DataScienceJourney(Tableau)
⭐ Topic : Tableau AND one SQL solved today!
🎸 Today , I explored :
🔥Visualization Charts in Tableau
-Filter
## 🔥 Visualization Charts in Tableau – Filters

### 🔹 What is a Filter in Tableau?

A **Filter** restricts the data shown in a visualization by including or excluding specific values. Filters help focus on relevant data and improve performance.

---

### 🔹 Types of Filters in Tableau

#### 1️⃣ **Extract Filters**

* Applied when creating an extract
* Reduce the size of the data extract
* Improve performance
* **Applied first** in the order of operations

📌 *Example:* Extract only data from the year 2024

---

#### 2️⃣ **Data Source Filters**

* Applied at the data source level
* Affect all sheets using that data source
* Useful for security and data restrictions

📌 *Example:* Show only “India” sales data

---

#### 3️⃣ **Context Filters**

* Create a subset of data
* Other filters depend on context filters
* Improves performance for large datasets

📌 *Example:* Region as a context filter, then filter customers within that region
➡ Right-click filter → **Add to Context**

---

#### 4️⃣ **Dimension Filters**

* Filter **categorical data**
* Can filter by:

  * Members
  * Wildcards
  * Conditions
  * Top N

📌 *Example:* Top 10 products by sales

---

#### 5️⃣ **Measure Filters**

* Filter **numerical values**
* Based on aggregated values

📌 *Example:* Sales > 50,000

---

#### 6️⃣ **Table Calculation Filters**

* Applied **last**
* Affect only the current view
* Do not change underlying data

📌 *Example:* Show only top 5 rows in a table

---

### 🔹 Order of Filters in Tableau (Very Important!)

1. Extract Filters
2. Data Source Filters
3. Context Filters
4. Dimension Filters
5. Measure Filters
6. Table Calculation Filters

---

### 🔹 Show Filter in Dashboard

* Drag field → Filters shelf
* Right-click → **Show Filter**
* Customize as:

  * Dropdown
  * Slider
  * Single value
  * Multiple values

---

### 🔹 Best Practices

✔ Use **context filters** for performance
✔ Avoid too many filters in dashboards
✔ Use **extract filters** for large datasets
✔ Use **parameter + filter** for dynamic control

---

### 🔹 Real-World Example

🎯 *Sales Dashboard*

* Data Source Filter → Country
* Context Filter → Year
* Dimension Filter → Product Category
* Measure Filter → Sales > 10,000

---

✨ **Pro Tip:** Always check the **Order of Operations** when filters don’t behave as expected!
