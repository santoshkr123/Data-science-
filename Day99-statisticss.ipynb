# %% [markdown]
# # Poisson and Normal (Gaussian) Distribution

# %% [markdown]
# # Poisson Distribution

# %% [markdown]
# The Poisson distribution is a discrete probability distribution that expresses the probability of a given number of events occurring in a fixed interval of time or space, given that these events happen with a known constant mean rate and independently of the time since the last event.
#
#
#
# Key Characteristics:
#
#
#
#
#
# Parameter: The Poisson distribution is characterized by a single parameter ( \lambda ) (lambda), which represents the average number of events in the interval.
#
#
#
# Probability Mass Function (PMF): The probability of observing ( k ) events in an interval is given by: [ P(X = k) = \frac{\lambda^k e^{-\lambda}}{k!} ] where ( k = 0, 1, 2, \ldots ) and ( e ) is the base of the natural logarithm.
#
#
#
# Mean and Variance: Both the mean and variance of a Poisson distribution are equal to ( \lambda ).
#
#
#
# Applications:
#
#
#
#
#
# Modeling the number of phone calls received by a call center in an hour.
#
#
#
# Counting the number of decay events per unit time from a radioactive source.
#
#
#
# Analyzing the number of arrivals at a service point in a given time period.

# %% [markdown]
# # Normal (Gaussian) Distribution

# %% [markdown]
# The Normal distribution, also known as the Gaussian distribution, is a continuous probability distribution that is symmetric about the mean, depicting the distribution of many types of real-valued random variables.
#
#
#
# Key Characteristics:
#
#
#
#
#
# Parameters: The Normal distribution is characterized by two parameters: the mean ( \mu ) and the standard deviation ( \sigma ).
#
#
#
# Probability Density Function (PDF): The probability density function of a Normal distribution is given by:
# [
# f(x) = \frac{1}{\sigma \sqrt{2\pi}} e^{-\frac{(x - \mu)^2}{2\sigma^2}}
# ]
#
#
#
# Mean, Median, and Mode: In a Normal distribution, the mean, median, and mode are all equal and located at the center of the distribution.
#
#
#
# Empirical Rule: Approximately 68% of the data falls within one standard deviation of the mean, about 95% within two standard deviations, and about 99.7% within three standard deviations.
#
#
#
# Applications:
#
#
#
#
#
# Modeling heights, weights, and test scores in a population.
#
#
#
# Analyzing measurement errors in experiments.
#
#
#
# Used in inferential statistics, such as hypothesis testing and confidence intervals.
