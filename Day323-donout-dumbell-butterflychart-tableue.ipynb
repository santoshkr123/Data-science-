# %%
🔷Day 323-DataScienceJourney(Tableau)
⭐ Topic : Tableau AND one SQL solved today!
🎸 Today , I explored :
🔥Visualization Charts in Tableau
-Donout Chart
A donut chart is a pie chart with a hole in the center.

✅ Use Case

Percentage contribution

Category share (Sales by Region, Profit by Segment)

🛠 How to Create

Drag your Dimension (e.g., Category) → Color.

Drag your Measure (e.g., Sales) → Angle.

Change Marks type → Pie.

Duplicate the measure (Ctrl + drag Sales again).

Create Dual Axis.

On the second Marks card:

Remove dimension

Set color to white

Reduce pie size

Synchronize axis & hide headers.

📌 Pro Tip

Add Total Sales as text in the center for storytelling.
                                     
-Dumbell chart
 A dumbbell chart compares two values across categories.

✅ Use Case

Actual vs Target

Sales 2023 vs 2024

Male vs Female comparison

🛠 How to Create

Drag Category → Rows.

Drag Measure 1 → Columns.

Drag Measure 2 → Columns.

Create Dual Axis.

Synchronize Axis.

Marks:

Measure 1 → Circle

Measure 2 → Circle

Add Line between circles:

Use Measure Names on Path OR

Create a calculated field for connecting line

📌 Pro Tip

Color circles differently to emphasize variance.                                    
                                     
                                     
-Butterfly chart
🦋 3. Butterfly Chart

A butterfly chart is a mirrored bar chart.

✅ Use Case

Male vs Female population

Revenue vs Cost

Planned vs Actual

🛠 How to Create

Drag Category → Rows.

Drag Measure A → Columns.

Drag Measure B → Columns.

Create a Calculated Field:

-[Measure B]


Replace Measure B with this negative version.

Use Bar Marks.

Fix axis range (symmetric).

Color each side differently.

📌 Pro Tip

Add labels inside bars for better readability.
