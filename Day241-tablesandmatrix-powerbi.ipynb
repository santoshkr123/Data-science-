# %% [markdown]
# # Tables and Matrix

# %%
🔥 Creating a Tables and Matrix
-Introduction Tables and Matrix
-Creating a Table in Power BI
-Formating style a Table in Power BI
-Apply Conditional Formatting 
-Changing Aggregations in Power BI
-Create a Matrix in Power BI
-Apply Conditional Formatting in Matrix
-Create Hierarchies in Power BI Matrxi
-Add Tables and Sub Totals In MAtrix
-How to change Number Formatting
