# %% [markdown]
# 📘 1. Random Variable
# A random variable is a variable whose value depends on the outcome of a random event.
#
# Two types:
#
# Discrete: Countable values (e.g., dice roll: 1, 2, 3, 4, 5, 6)
#
# Continuous: Infinite values in a range (e.g., height, weight)

# %% [markdown]
# 🔢 2. Set Operations in Statistics
# Useful in probability and event analysis.
#
# Union (A ∪ B): Elements in A, or B, or both
# → All outcomes in either set
#
# Intersection (A ∩ B): Elements common to both A and B
# → Shared outcomes
#
# Difference (A - B): Elements in A but not in B
# → Exclude B’s outcomes from A
#
# Subset (A ⊆ B): All elements of A are in B
#
# Superset (A ⊇ B): A contains all elements of B

# %% [markdown]
# 📊 3. Histogram and Skewness
# Histogram: Graph showing frequency distribution.
#
# Skewness: Measures asymmetry in data.
#
# Types of Skewness:
# Type	Tail	Mean vs Median
# No skew (symmetrical)	Even tails	Mean = Median = Mode
# Right skew (positive)	Long right tail	Mean > Median
# Left skew (negative)	Long left tail	Mean < Median

# %% [markdown]
# 📈 4. Normal / Gaussian Distribution
# Bell-shaped curve
#
# Properties:
#
# Symmetrical
#
# Mean = Median = Mode
#
# 68-95-99.7 Rule:
#
# 68% within 1 std dev
#
# 95% within 2
#
# 99.7% within 3
