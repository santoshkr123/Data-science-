# %%
🔷Day 311-DataScienceJourney(Tableau)
 ⭐ Topic : Tableau
🎸 Today , I explored :
-Introduction to Tableau
-Goals of Tableau
-Benefits of Tableau
-Tableau Vs Power BI
-Tableau desktop vs Tableau public
-General interface of Tableau

*Introduction
-Tableau is a groundbreaking data visualization software created by Tableau software
-Tableau connects easily to nearly any data source

*Goals of Tableau
-To create data visualization applications used in the Business Intelligence
Industry
-To aid in the simplification of raw data
-To assist in the creation of data that can be grasped by people at all stages of an organization
-To analyses data swifty and delivers visualization in the form of dashboards or workbooks

*Benefits of Tableau :
-User-friendly and interations
-Simple drag and drop
-Speedy performance 
-Integeration of several data sources 
-easy publishing 
-Aesthetically rich visualization 
-Huge data handling 

*Difference Power BI and Tableau
Power BI
-Microsoft
-2013
-Cost-effective
The pro-plan starts at $9.99per month
-no license keys are required
-small,meduim,and large datastes
_power BI uses Dax(Data Analytics Expression)for
calculated columns and measures
-It can handle a limited volume of data
Easier to learn and use


Tableau
-Salesforce 
-2003
-Costly basic creator bundle starts at $70 per month per user 
-License keys are required 
-Large enterprises
-Tableau employs MDX(Multidimensional Expression )for dimension and measures
-It can handle a huge volume of data with better performance 
-Takes time and expertise to master
