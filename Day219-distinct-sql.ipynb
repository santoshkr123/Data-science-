# %%
 Distinct(uniue) values from a column
 Distinct Combinations

📌 select distinct brand_name
from smartphones_cleaned_v6;

📌select distinct processor_brand
from smartphones_cleaned_v6;

📌select distinct brand_name , processor_brand
from smartphones_cleaned_v6;
