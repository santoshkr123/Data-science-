# %%
🔷Day 256-DataScienceJourney(POWER BI)
 ⭐ Topic : DAX AND SQL LEETCODE SOLVED
🎸 Today , I explored :
🔥 Data modelling
-What is Data modelling
-Schema[Flat schema, schema, snowflake schema]
-Fact Table
-Dimension Table
-Cross-Filter Direction
-Related Function
-RelatedTable Function
-Cross-Filter Function
