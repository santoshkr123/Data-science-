# %% [markdown]
# # Time Series Implementation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import sys

# %%
data=pd.read_csv('TSLA.CSV')

# %%
data.head()
# Out:
#          Date       Open       High        Low      Close     Volume  \
# 0  2019-05-21  39.551998  41.480000  39.208000  41.015999   90019500
# 1  2019-05-22  39.820000  40.787998  38.355999  38.546001   93426000
# 2  2019-05-23  38.868000  39.894001  37.243999  39.098000  132735500
# 3  2019-05-24  39.966000  39.995998  37.750000  38.125999   70683000
# 4  2019-05-28  38.240002  39.000000  37.570000  37.740002   51564500
#
#    Dividends  Stock Splits
# 0          0           0.0
# 1          0           0.0
# 2          0           0.0
# 3          0           0.0
# 4          0           0.0

# %%
stock_data=data[['Date','Close']]

# %%
stock_data
# Out:
#            Date       Close
# 0    2019-05-21   41.015999
# 1    2019-05-22   38.546001
# 2    2019-05-23   39.098000
# 3    2019-05-24   38.125999
# 4    2019-05-28   37.740002
# ..          ...         ...
# 753  2022-05-16  724.369995
# 754  2022-05-17  761.609985
# 755  2022-05-18  709.809998
# 756  2022-05-19  709.419983
# 757  2022-05-20  663.900024
#
# [758 rows x 2 columns]

# %%
stock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 758 entries, 0 to 757
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    758 non-null    object
#  1   Close   758 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 12.0+ KB

# %%
stock_data['Date']=pd.to_datetime(stock_data['Date'])
# Out:
# C:\Users\santo\AppData\Local\Temp\ipykernel_22784\3223040857.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_data['Date']=pd.to_datetime(stock_data['Date'])

# %%
stock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 758 entries, 0 to 757
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    758 non-null    datetime64[ns]
#  1   Close   758 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 12.0 KB

# %%
stock_data.head(2)
# Out:
#         Date      Close
# 0 2019-05-21  41.015999
# 1 2019-05-22  38.546001

# %% [markdown]
# why are we converting date columns to index
# 1.easily retrive data
# 2.visualization is easy
# 3.those lib has been design in such that way it replaced date columns  as index

# %%
stock_data=stock_data.set_index('Date')

# %%
stock_data
# Out:
#                  Close
# Date
# 2019-05-21   41.015999
# 2019-05-22   38.546001
# 2019-05-23   39.098000
# 2019-05-24   38.125999
# 2019-05-28   37.740002
# ...                ...
# 2022-05-16  724.369995
# 2022-05-17  761.609985
# 2022-05-18  709.809998
# 2022-05-19  709.419983
# 2022-05-20  663.900024
#
# [758 rows x 1 columns]

# %%
stock_data.describe()
# Out:
#              Close
# count   758.000000
# mean    485.531513
# std     353.160353
# min      35.793999
# 25%     112.323500
# 50%     488.125000
# 75%     762.142502
# max    1229.910034

# %%
plt.plot(stock_data.Close)

# %%
plt.hist(stock_data.Close)
# Out:
# (array([228.,  57.,  38.,  59.,  50., 127.,  81.,  44.,  59.,  15.]),
#  array([  35.79399872,  155.20560226,  274.61720581,  394.02880936,
#          513.4404129 ,  632.85201645,  752.26362   ,  871.67522354,
#          991.08682709, 1110.49843063, 1229.91003418]),
#  <BarContainer object of 10 artists>)

# %%
#plotting close price
plt.style.use('ggplot')
plt.figure(figsize=(18,8))
plt.grid(True)
plt.xlabel('Dates',fontsize=20)
plt.xticks(fontsize=15)
plt.ylabel('Close Prices',fontsize=20)
plt.yticks(fontsize=15)
plt.plot(stock_data['Close'],linewidth=3,color='blue')
plt.title('Tesla Stock Closing Price',fontsize=30)
# Out:
# Text(0.5, 1.0, 'Tesla Stock Closing Price')

# %%
#plotting close price
plt.style.use('ggplot')
plt.figure(figsize=(18,8))
plt.grid(True)
plt.xlabel('Dates',fontsize=20)
plt.xticks(fontsize=15)
plt.ylabel('Close Prices',fontsize=20)
plt.yticks(fontsize=15)
plt.hist(stock_data['Close'],linewidth=3,color='blue')
plt.title('Tesla Stock Closing Price',fontsize=30)
# Out:
# Text(0.5, 1.0, 'Tesla Stock Closing Price')

# %%
df_close=stock_data['Close']
df_close.plot(kind='kde',figsize=(18,8),linewidth=3)
plt.xticks(fontsize=15)
plt.grid('both')
plt.ylabel('Density',fontsize=20)
plt.yticks(fontsize=15)
plt.show()

# %%
rolmean=stock_data['Close'].rolling(3).mean()

# %%
stdmean=stock_data['Close'].rolling(3).std()

# %%
plt.plot(stock_data.Close)
plt.plot(rolmean)
plt.plot(stdmean)

# %%
from statsmodels.tsa.stattools import adfuller
adft=adfuller(stock_data['Close'])

# %%
pd.Series(adft[0:4],index=['test_stats','p-value','lag','data points'])
# Out:
# test_stats      -1.363009
# p-value          0.599876
# lag              9.000000
# data points    748.000000
# dtype: float64

# %%
def test_stationarity(timeseries):
    # Determing rolling statistics
    rolmean = timeseries.rolling(48).mean() # rolling mean
    rolstd = timeseries.rolling(48).std() # rolling standard deviation
    # Plot rolling statistics:
    plt.figure(figsize = (18,8))
    plt.grid('both')
    plt.plot(timeseries, color='blue',label='Original', linewidth = 3)
    plt.plot(rolmean, color='red', label='Rolling Mean',linewidth = 3)
    plt.plot(rolstd, color='black', label = 'Rolling Std',linewidth = 4)
    plt.legend(loc='best', fontsize = 20, shadow=True,facecolor='lightpink',edgecolor = 'k')
    plt.title('Rolling Mean and Standard Deviation', fontsize = 25)
    plt.xticks(fontsize = 15)
    plt.yticks(fontsize = 15)
    plt.show(block=False)

    print("Results of dickey fuller test")
    adft = adfuller(timeseries,autolag='AIC')
    # output for dft will give us without defining what the values are.
    # hence we manually write what values does it explains using a for loop
    output = pd.Series(adft[0:4],index=['Test Statistics','p-value','No. of lags used','Number of observations used'])
    for key,values in adft[4].items():
        output['critical value (%s)'%key] =  values
    print(output)

# %%
test_stationarity(stock_data.Close)
# Out:
# Results of dickey fuller test
# Test Statistics                 -1.363009
# p-value                          0.599876
# No. of lags used                 9.000000
# Number of observations used    748.000000
# critical value (1%)             -3.439123
# critical value (5%)             -2.865412
# critical value (10%)            -2.568832
# dtype: float64

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
result=seasonal_decompose(stock_data[['Close']],period=12)

# %%
result.seasonal
# Out:
# Date
# 2019-05-21   -2.346452
# 2019-05-22    3.768884
# 2019-05-23   -0.777006
# 2019-05-24   -0.654226
# 2019-05-28   -2.737845
#                 ...
# 2022-05-16    2.149519
# 2022-05-17    1.323680
# 2022-05-18    1.837638
# 2022-05-19   -2.346452
# 2022-05-20    3.768884
# Name: seasonal, Length: 758, dtype: float64

# %%
fig=plt.figure(figsize=(20,10))
fig=result.plot()
fig.set_size_inches(17,10)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
result=seasonal_decompose(stock_data[['Close']],period=12,model='multiplicative')

# %%
fig=plt.figure(figsize=(20,10))
fig=result.plot()
fig.set_size_inches(17,10)

# %%
import seaborn as sns
sns.boxplot(stock_data.Close)
# Out:
# <Axes: ylabel='Close'>

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
plot_acf(stock_data.Close)
plot_pacf(stock_data.Close)

# %% [markdown]
# # convert non-stationar to stationary

# %%
df_close=stock_data['Close']

# %%
df_close
# Out:
# Date
# 2019-05-21     41.015999
# 2019-05-22     38.546001
# 2019-05-23     39.098000
# 2019-05-24     38.125999
# 2019-05-28     37.740002
#                  ...
# 2022-05-16    724.369995
# 2022-05-17    761.609985
# 2022-05-18    709.809998
# 2022-05-19    709.419983
# 2022-05-20    663.900024
# Name: Close, Length: 758, dtype: float64

# %%
df_close=df_close.diff()

# %%
df_close
# Out:
# Date
# 2019-05-21          NaN
# 2019-05-22    -2.469997
# 2019-05-23     0.551998
# 2019-05-24    -0.972000
# 2019-05-28    -0.385998
#                 ...
# 2022-05-16   -45.220032
# 2022-05-17    37.239990
# 2022-05-18   -51.799988
# 2022-05-19    -0.390015
# 2022-05-20   -45.519958
# Name: Close, Length: 758, dtype: float64

# %%
df_close=df_close.dropna()

# %%
df_close
# Out:
# Date
# 2019-05-22    -2.469997
# 2019-05-23     0.551998
# 2019-05-24    -0.972000
# 2019-05-28    -0.385998
# 2019-05-29     0.231998
#                 ...
# 2022-05-16   -45.220032
# 2022-05-17    37.239990
# 2022-05-18   -51.799988
# 2022-05-19    -0.390015
# 2022-05-20   -45.519958
# Name: Close, Length: 757, dtype: float64

# %%
test_stationarity(df_close)
# Out:
# Results of dickey fuller test
# Test Statistics               -8.324564e+00
# p-value                        3.498786e-13
# No. of lags used               8.000000e+00
# Number of observations used    7.480000e+02
# critical value (1%)           -3.439123e+00
# critical value (5%)           -2.865412e+00
# critical value (10%)          -2.568832e+00
# dtype: float64

# %%
df_close[0:-60]
# Out:
# Date
# 2019-05-22    -2.469997
# 2019-05-23     0.551998
# 2019-05-24    -0.972000
# 2019-05-28    -0.385998
# 2019-05-29     0.231998
#                 ...
# 2022-02-17   -47.040039
# 2022-02-18   -19.369995
# 2022-02-22   -35.449951
# 2022-02-23   -57.490051
# 2022-02-24    36.730042
# Name: Close, Length: 697, dtype: float64

# %%
df_close[-60:]
# Out:
# Date
# 2022-02-25      9.099976
# 2022-02-28     60.559998
# 2022-03-01     -6.059998
# 2022-03-02     15.520020
# 2022-03-03    -40.600037
# 2022-03-04     -1.000000
# 2022-03-07    -33.709961
# 2022-03-08     19.820007
# 2022-03-09     34.569946
# 2022-03-10    -20.669983
# 2022-03-11    -42.950012
# 2022-03-14    -28.979980
# 2022-03-15     35.520020
# 2022-03-16     38.339966
# 2022-03-17     31.369995
# 2022-03-18     33.790039
# 2022-03-21     15.769958
# 2022-03-22     72.820007
# 2022-03-23      5.130005
# 2022-03-24     14.809998
# 2022-03-25     -3.279968
# 2022-03-28     81.199951
# 2022-03-29      7.729980
# 2022-03-30     -5.579956
# 2022-03-31    -16.390015
# 2022-04-01      6.989990
# 2022-04-04     60.859985
# 2022-04-05    -54.189941
# 2022-04-06    -45.500000
# 2022-04-07     11.500000
# 2022-04-08    -31.770020
# 2022-04-11    -49.559998
# 2022-04-12     11.020020
# 2022-04-13     35.419983
# 2022-04-14    -37.369995
# 2022-04-18     19.289978
# 2022-04-19     23.860046
# 2022-04-20    -50.950012
# 2022-04-21     31.580017
# 2022-04-22     -3.730042
# 2022-04-25     -7.029968
# 2022-04-26   -121.600037
# 2022-04-27      5.090027
# 2022-04-28     -4.000000
# 2022-04-29     -6.750000
# 2022-05-02     32.179993
# 2022-05-03      6.309998
# 2022-05-04     43.369995
# 2022-05-05    -79.339966
# 2022-05-06     -7.630005
# 2022-05-09    -78.540039
# 2022-05-10     12.929993
# 2022-05-11    -66.039978
# 2022-05-12     -6.000000
# 2022-05-13     41.590027
# 2022-05-16    -45.220032
# 2022-05-17     37.239990
# 2022-05-18    -51.799988
# 2022-05-19     -0.390015
# 2022-05-20    -45.519958
# Name: Close, dtype: float64

# %%
train_data = df_close[0:-60]
test_data = df_close[-60:]
plt.figure(figsize=(18,8))
plt.grid(True)
plt.xlabel('Dates', fontsize=20)
plt.ylabel('Closing Prces', fontsize=20)
plt.plot(train_data,'green', label='Train Data')
plt.plot(test_data,'blue',label='Test Data')

# %% [markdown]
# # Model building

# %%
import statsmodels.api as sm
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
history = [x for x in train_data]

# %%
history
# Out:
# [-2.4699974060058594,
#  0.5519981384277415,
#  -0.9720001220703125,
#  -0.385997772216804,
#  0.23199844360351562,
#  -0.3279991149902344,
#  -0.61199951171875,
#  -1.2380027770996094,
#  2.9260025024414062,
#  0.5979995727539062,
#  1.871997833251946,
#  -0.289997100830071,
#  1.6759986877441406,
#  0.8439979553222656,
#  -1.5679969787597656,
#  0.9300003051757812,
#  0.20199966430664062,
#  2.0219993591308594,
#  -0.0579986572265625,
#  0.3379974365234375,
#  -1.36199951171875,
#  0.4480018615722656,
#  0.3559989929199219,
#  -0.7760009765625,
#  -0.09799957275390625,
#  0.7140007019042969,
#  0.12400054931640625,
#  0.7419967651367259,
#  -0.523998260498054,
#  2.0699996948242188,
#  -0.3600006103515625,
#  -0.5519981384277344,
#  -0.055999755859375,
#  1.7719993591308665,
#  -0.06399917602539773,
#  1.2959976196289062,
#  1.6840019226074219,
#  -0.2239990234375,
#  0.4959983825683594,
#  -0.26399993896484375,
#  0.9280014038085938,
#  -0.5,
#  0.8979988098144602,
#  0.9420013427734304,
#  -7.212001800537102,
#  -0.15599822998047586,
#  1.5459976196289062,
#  1.2980003356933594,
#  -0.13000106811523438,
#  -1.5519981384277344,
#  0.09799957275390625,
#  -1.2039985656738281,
#  0.48600006103515625,
#  0.5339965820312571,
#  0.976001739501946,
#  -0.6580009460449219,
#  -1.2000007629394602,
#  1.1980018615722727,
#  -3.076000213623047,
#  -0.7960014343261719,
#  0.8600006103515554,
#  1.378002166748054,
#  -0.194000244140625,
#  -1.0060005187988281,
#  0.26399993896484375,
#  -2.150001525878899,
#  0.7200012207031179,
#  -0.18399810791016336,
#  -31.88995361328125,
#  10.1199951171875,
#  -21.67999267578125,
#  -7.4200439453125,
#  24.33001708984375,
#  32.30999755859375,
#  -6.17999267578125,
#  29.29998779296875,
#  0.57000732421875,
#  -20.6500244140625,
#  12.83001708984375,
#  -6.77996826171875,
#  24.9599609375,
#  60.34002685546875,
#  -30.09002685546875,
#  6.6199951171875,
#  0.9300537109375,
#  -25.1500244140625,
#  4.3599853515625,
#  25.1300048828125,
#  -24.42999267578125,
#  9.71002197265625,
#  8.79998779296875,
#  -33.46002197265625,
#  -10.3399658203125,
#  -17.4000244140625,
#  32.44000244140625,
#  -24.53997802734375,
#  -11.300048828125,
#  -2.65997314453125,
#  -7.4000244140625,
#  8.83001708984375,
#  -43.33001708984375,
#  -11.8399658203125,
#  -27.30999755859375,
#  -18.20001220703125,
#  18.04998779296875,
#  -12.90997314453125,
#  1.03997802734375,
#  -14.40997314453125,
#  23.32000732421875,
#  -5.9000244140625,
#  25.55999755859375,
#  -1.75,
#  14.44000244140625,
#  11.719970703125,
#  -5.6300048828125,
#  -1.3199462890625,
#  -18.780029296875,
#  -32.27996826171875,
#  26.2099609375,
#  6.08001708984375,
#  -1.53997802734375,
#  -4.80999755859375,
#  11.3399658203125,
#  -0.22998046875,
#  7.79998779296875,
#  -18.33001708984375,
#  5.510009765625,
#  11.72998046875,
#  6.71002197265625,
#  -2.47998046875,
#  2.8800048828125,
#  32.8599853515625,
#  23.25,
#  -7.95001220703125,
#  16.8499755859375,
#  -7.9599609375,
#  -1.05999755859375,
#  -1.780029296875,
#  0.98004150390625,
#  -19.32000732421875,
#  -14.92999267578125,
#  8.15997314453125,
#  4.1400146484375,
#  28.75,
#  -17.1600341796875,
#  -15.15997314453125,
#  -2.780029296875,
#  -6.3800048828125,
#  2.0,
#  14.280029296875,
#  -5.21002197265625,
#  -6.02996826171875,
#  -5.8800048828125,
#  14.239990234375,
#  -12.8399658203125,
#  2.199951171875,
#  30.3699951171875,
#  9.85003662109375,
#  22.469970703125,
#  0.07000732421875,
#  1.17999267578125,
#  3.71002197265625,
#  -15.530029296875,
#  14.6600341796875,
#  -3.77001953125,
#  -2.16998291015625,
#  14.42999267578125,
#  -5.08001708984375,
#  -31.0,
#  -20.4599609375,
#  23.27996826171875,
#  -15.52001953125,
#  6.7900390625,
#  26.03997802734375,
#  2.19000244140625,
#  2.71002197265625,
#  -10.0400390625,
#  10.760009765625,
#  18.989990234375,
#  4.80999755859375,
#  -1.62994384765625,
#  -1.70001220703125,
#  1.17999267578125,
#  19.3499755859375,
#  0.95001220703125,
#  0.989990234375,
#  -18.5899658203125,
#  6.72998046875,
#  1.489990234375,
#  11.34002685546875,
#  1.15997314453125,
#  2.5,
#  -29.32000732421875,
#  9.21002197265625,
#  12.55999755859375,
#  1.70001220703125,
#  20.75,
#  16.969970703125,
#  -13.79998779296875,
#  3.75,
#  -5.83001708984375,
#  -0.260009765625,
#  6.31005859375,
#  -0.94000244140625,
#  2.15997314453125,
#  10.8599853515625,
#  -8.1199951171875,
#  6.45001220703125,
#  13.77996826171875,
#  5.36004638671875,
#  7.239990234375,
#  24.71002197265625,
#  27.0799560546875,
#  -5.8399658203125,
#  1.52996826171875,
#  28.20001220703125,
#  15.67999267578125,
#  115.17999267578125,
#  -6.42999267578125,
#  19.42999267578125,
#  39.1800537109375,
#  36.9599609375,
#  94.5899658203125,
#  -36.5899658203125,
#  41.8599853515625,
#  16.050048828125,
#  -7.820068359375,
#  -59.1500244140625,
#  -139.43994140625,
#  44.449951171875,
#  -4.43994140625,
#  -30.0899658203125,
#  -20.030029296874886,
#  41.339965820312386,
#  34.280029296875,
#  7.3699951171875,
#  40.6800537109375,
#  19.8099365234375,
#  -47.8399658203125,
#  6.969970703125,
#  -34.0799560546875,
#  55.0699462890625,
#  7.77001953125,
#  -49.760009765625,
#  -10.4000244140625,
#  -69.6300048828125,
#  -5.9599609375,
#  42.739990234375,
#  17.2099609375,
#  -65.15997314453125,
#  13.23004150390625,
#  -50.62005615234375,
#  -7.89996337890625,
#  17.47998046875,
#  -49.07000732421875,
#  5.6500244140625,
#  -32.6300048828125,
#  38.59002685546875,
#  70.33996582031261,
#  58.130004882812386,
#  26.93994140625,
#  -5.469970703125,
#  -2.280029296875,
#  -15.8499755859375,
#  -13.5599365234375,
#  143.0,
#  -50.1900634765625,
#  -61.469970703125,
#  -23.4200439453125,
#  -37.739990234375,
#  31.1600341796875,
#  6.280029296875,
#  41.8199462890625,
#  -74.659912109375,
#  18.0499267578125,
#  -19.0999755859375,
#  -34.859985351562614,
#  0.6199951171876137,
#  -52.369995117187614,
#  -13.900024414062386,
#  -11.599975585937614,
#  19.009948730468864,
#  -108.30999755859375,
#  17.25,
#  90.3699951171875,
#  -5.469970703125,
#  -25.59002685546875,
#  -14.51995849609375,
#  32.17999267578125,
#  -15.97998046875,
#  14.65997314453125,
#  10.0,
#  -27.45001220703125,
#  -44.54998779296875,
#  15.760009765625,
#  46.66998291015625,
#  0.9600219726563637,
#  -47.040039062500114,
#  -19.3699951171875,
#  -35.449951171875,
#  -57.49005126953125,
#  36.73004150390625]

# %%
model = ARIMA(history, order =(1,1,1))

# %%
model = model.fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  697
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -3148.870
# Date:                Sun, 20 Jul 2025   AIC                           6303.741
# Time:                        13:09:42   BIC                           6317.377
# Sample:                             0   HQIC                          6309.013
#                                 - 697
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0285      0.025     -1.150      0.250      -0.077       0.020
# ma.L1         -0.9991      0.012    -81.343      0.000      -1.023      -0.975
# sigma2       493.6006     12.978     38.035      0.000     468.165     519.036
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              2092.37
# Prob(Q):                              0.95   Prob(JB):                         0.00
# Heteroskedasticity (H):              31.85   Skew:                             0.02
# Prob(H) (two-sided):                  0.00   Kurtosis:                        11.49
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
model.forecast()[0]
# Out:
# 0.04741555878192116

# %%
test_data[0]
# Out:
# C:\Users\santo\AppData\Local\Temp\ipykernel_22784\2395562395.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   test_data[0]
# 9.0999755859375

# %%
mean_squared_error([test_data[0]],model.forecast())
# Out:
# C:\Users\santo\AppData\Local\Temp\ipykernel_22784\3878667994.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   mean_squared_error([test_data[0]],model.forecast())
# 81.94884304525502

# %%
np.sqrt(mean_squared_error([test_data[0]],model.forecast()))
# Out:
# C:\Users\santo\AppData\Local\Temp\ipykernel_22784\2013795996.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   np.sqrt(mean_squared_error([test_data[0]],model.forecast()))
# 9.052560027155579
