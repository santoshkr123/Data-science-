# %%
☑️ Filter rows WHERE clause and operator 
☑️BETWEEN operator
☑️IN and NOT IN operator

select * 
from smartphones_cleaned_v6
where price > 25000

select * 
from smartphones_cleaned_v6
where price > 12000 and price < 25000;

select * 
from smartphones_cleaned_v6
where price between 12000 and 25000;

select * 
from smartphones_cleaned_v6
where price < 25000 and rating > 70;

select * 
from smartphones_cleaned_v6
where price < 15000 and rating > 70 and brand_name='samsung';

select * 
from smartphones_cleaned_v6
where brand_name not in('samsung','realme','oneplus');
