# %% [markdown]
# 📌 Support Vector Machine (SVM) – Simplified
# SVM is a supervised machine learning algorithm used for both classification and regression tasks — but it's mostly known for classification.
#
# 🧠 Core Idea:
# It finds the best boundary (hyperplane) that separates different classes of data with the maximum margin — meaning the widest possible gap between categories.

# %% [markdown]
# 🤖 Support Vector Classifier (SVC)
# SVC is the classification implementation of SVM in scikit-learn.
#
# ✅ Key Features:
#
# Works well on high-dimensional data.
#
# Uses support vectors — critical data points closest to the decision boundary.

# %% [markdown]
# 📈 Example Use Cases:
# Spam detection
#
# Face recognition
#
# Bioinformatics
